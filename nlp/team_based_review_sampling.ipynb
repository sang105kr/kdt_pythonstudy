# %%
# !pip install KoNLPy

# %%
# 데이터 분석
import pandas as pd
import numpy as np

# %%
# 시각화
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
# 정규표현식
import re

# %%
# 형태소분석
from konlpy.tag import Okt
okt = Okt()

# %%
# 시간
import time

# %%
df_1t = pd.read_csv('./data/nlp_1t.csv',encoding='cp949')
display(df_1t)
# Out:
#                                                review label1  label2
# 0   [[山] 2024, 가은산 … 2. 충주 악어봉소재지 : 충청북도 충주시 살미면 무...    가은산       1
# 1   [??폭염을 피해서 산으로가다  ??동해에 해가 떠오른다  ?? 여차저차 많은 이야...    가은산       0
# 2   [2023.06.25가은산(제천), 575m7km, 4시간 30분옥순봉 쉼터-가은산...    가은산       0
# 3   [7.  충북제천 가은산(575m)충청북도 제천시 수산면에 있는 산으로 높이 575...    가은산       1
# 4   [금수산~가은산 연계산행은 비록 거리는 13km에 불과하였지만,난이도는 웬만한 산행...    가은산       1
# 5   [안녕하세요??에코 리더 공인중개사 사무소입니다.잘 기억은 안나지만 어렴풋이 15년...    대둔산       1
# 6   [2년만에 찾은 대둔산.코스는 우리팀 형님이 찾은 새천년릿지.첨 들어봤기에 블로그 ...    대둔산       1
# 7   [대둔산으로 드라이브 겸 등산하러 갔다옴대전에서 1시간 정도 걸리는 거리??일단 가...    대둔산       0
# 8   [*대둔산 둘레길* 코스 : 대둔산 주차장-케이블타 - 취수정-석독골-노론이계곡-노...    대둔산       0
# 9   [지난 11월 13일 월요일, 전북 완주에 있는 대둔산에 다녀왔습니다. 멀리서 봤을...    대둔산       0
# 10  [로프, 또 로프.눈이 얼어 발 붙일 곳 없는데, 로프는 왜 이리 많은지.구왕봉에서...    희양산       0
# 11  [  ∞   ∞   산행 일자 : 2017. 5. 3 (수) 부처님오신날산행지 : ...    희양산       1
# 12  [덥다. 장마가 잠시 주춤하면서  해가 얼굴을 내미니 마음은 가벼운데 햇볕은 숨이 ...    희양산       0
# ...

# %%
df_2t = pd.read_csv('./data/nlp_2t.csv',encoding='utf-8')
display(df_2t)
# Out:
#                                                review  label1  label2
# 0   지인이 추천해서 왔는데 시설도 깨끗하고 직원분들도 친절하네요^^아이와 왔는데 재밌는...      문화       1
# 1           완전좋아요\n가격이 꽤 나가서 일찍 가서 여유있게 놀다오는거\n추천드립니다      문화       1
# 2                                운동장에 눈이 있어 미끄러워 아쉽네요      문화       0
# 3                평소랑 다르게 오늘은 삐뚤삐뚤하게 삐죽 삐져나온게 너무많아요 ㅠ       미용       0
# 4   벌써 4번째 방문인데 오늘도 넘 만족스럽게 미용해주셨어여 귀가 넘 귀엽..♡제가 스...      미용       1
# 5   항상 멍이날개에서 미용하는데 리뷰는 처음이네요 ㅎㅎ 저번에 미용하고 나서 털이 많이...      미용       1
# 6                               생각보다 찾는게 많이 없어서 아쉬웠어요  반려동물용품       0
# 7   최근 가본곳 중에 댕댕이 냐옹이 용품 종류가 제일 다양해요! 저희 집 댕댕이 국산 ...  반려동물용품       1
# 8   용품 몇개 구입하러 방문했는데 사장님과 직원분이 열정적으로 설명해주시고 보여주시더라...  반려동물용품       1
# 9   숙소좋아요 3일동안 너무잘지내다왔어요 조용하고 산책좋아하시면 여기숙소 추천해요 그리...   위탁및숙박       1
# 10  스파도 있고, 펜션 뒤에 산책로도 있어 강아지랑 올라갔다 왔어요. 다만, 펜션 방음...   위탁및숙박       0
# 11  친구들과 15주년 여행으로 고른 숙소에요!! 애견동반이라 냄새날까 걱정이 많이 되었...   위탁및숙박       1
# ...

# %%
df_3t = pd.read_csv('./data/nlp_3t.csv',encoding='utf-8')
display(df_3t)
# Out:
#                                                review label1  label2
# 0   챠슈카츠정식은 할라피뇨소스를 추가하시면 덜 느끼하게 먹기 좋아요 살짝 비린맛이나요닭...     퓨전       0
# 1                         사람이 많아요.주차장이 없어 유료 주차 해야해요.     퓨전       0
# 2   이중생업 맛없다 하는 사람도 있나요 진차 JMT💖데이트 장소로도 찰떡이구 .. 오후...     퓨전       1
# 3   음식도 맛있었고 분위기도 좋았는데 마감 때쯤 방문해서 아직 손님들이 밥 먹고 있는데...     퓨전       0
# 4   으앗 너무좁고 비좁고 첨엔맛있었는데 갈수록 느끼해져서 다못먹고 남겼어요 첨에딱먹을때...     퓨전       0
# 5             주차장 넓어서 주차하기 너무 좋아요 근데 파인애플차는 너무 맛없어요ㅜㅜ     카페       0
# 6   골든드롭이야,뷰 특히 야경뷰좋은건 인정..커피나 빵은 맛있는데,수제청들은 너~~~무...     카페       0
# 7   주차장이 넓지만 사람이 워낙 많아서 주차장도 만차이네요. 음료나 빵종류가 다양하고 ...     카페       0
# 8                    주차하기도 좋고뷰도좋고 빵도 맛나고친구들과 대화하기 좋아요     카페       1
# 9   브리즈넛 진심 푹 빠졌어요 넘 맛있음ㅜㅜㅜ아메리카노듀 향좋고 에르메스잔에 나와서 더...     카페       1
# 10  울산 초밥 맛집 가성비 👍👍👍^^울산 삼산 상무초밥맛   서비스 친절 최고입니다.혼...     일식       1
# 11  매장이 깨끗하고 직원분들이 친절하셔서 친구랑 편하게 먹었어요‘! 자리도 2인석 4인...     일식       1
# 12  매장에서 먹는건 두번째 방문입니다! 점심특선 구성이 가성비 너무 좋구요 첫번째 방문...     일식       1
# ...

# %% [markdown]
# * 품사태그표 :
#     * https://konlpy.org/ko/v0.6.0/morph/
#     * https://docs.google.com/spreadsheets/d/1OGAjUvalBuX-oZvZ_-9tEfYD2gQe7hTGsgUpiiBSXI8/edit#gid=0

# %%
def extract_korean_from_series(series):
    # 정규 표현식을 사용하여 한글만 추출
    def extract_korean(text):
        
        # 한글과 공백만 추출
        text = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣\s]','',text)
        # 공백 2개 이상인경우 1개로 변환
        text = re.sub(r'\s+',' ',text)
    
        return text

    # 시리즈의 각 요소에 대해 한글 추출 함수 적용
    return series.map(extract_korean)

# %%
# 시리즈에서 중복을 제거한 형용사와 동사 추출 후 리스트로 반환
def extract_adjectives_from_series_by_okt(analyzer, series):
    words = set()  # 중복을 제거하기 위해 집합 사용

    # 시리즈의 각 요소에 대해 반복
    for i, text in enumerate(series):
        start = time.time()
        analyzer_pos = analyzer.pos(text)
        for word, pos in analyzer_pos:
            # 한글자 제외
            if len(word) == 1 :
                continue
            if pos == 'Verb' or pos == 'Adjective':
                words.add((pos, word))

        print(f'{i+1}번째 수행.../ 소요시간 : {time.time() - start}')

    # (품사, 단어) 형식의 튜플을 리스트로 변경하여 반환
    return [[pos, word] for pos, word in words]

# %%
df_1t['review2'] = extract_korean_from_series(df_1t['review'])
df_1t.head(2)
df_1t['review2_len'] = df_1t['review2'].map(len)
df_1t.head(5)
# Out:
#                                               review label1  label2  \
# 0  [[山] 2024, 가은산 … 2. 충주 악어봉소재지 : 충청북도 충주시 살미면 무...    가은산       1
# 1  [??폭염을 피해서 산으로가다  ??동해에 해가 떠오른다  ?? 여차저차 많은 이야...    가은산       0
# 2  [2023.06.25가은산(제천), 575m7km, 4시간 30분옥순봉 쉼터-가은산...    가은산       0
# 3  [7.  충북제천 가은산(575m)충청북도 제천시 수산면에 있는 산으로 높이 575...    가은산       1
# 4  [금수산~가은산 연계산행은 비록 거리는 13km에 불과하였지만,난이도는 웬만한 산행...    가은산       1
#
#                                              review2  review2_len
# 0   가은산 충주 악어봉소재지 충청북도 충주시 살미면 무릉리 산 당일식사를 마치는 시각...         3025
# 1  폭염을 피해서 산으로가다 동해에 해가 떠오른다 여차저차 많은 이야기 들을 하면서 산...          533
# 2  가은산제천 시간 분옥순봉 쉼터가은산전망대가늠산상천마을 갈림길옥순봉쉼터월악산 국립공원...         1549
# 3   충북제천 가은산충청북도 제천시 수산면에 있는 산으로 높이 동쪽이 단양군 단양읍적성...         1363
# 4  금수산가은산 연계산행은 비록 거리는 에 불과하였지만난이도는 웬만한 산행 이상을 한 ...         4672

# %%
df_1t['review2_len'].describe()
# Out:
# count      20.000000
# mean     1797.450000
# std       956.386152
# min       533.000000
# 25%      1192.500000
# 50%      1499.500000
# 75%      2215.750000
# max      4672.000000
# Name: review2_len, dtype: float64

# %%
# 문자길이가 3000 이상인행 삭제
# df_1t.drop(df_1t[df_1t['review2_len'] >= 3000].index, inplace=True)

# %%
df_2t['review2'] = extract_korean_from_series(df_2t['review'])
df_2t.head(2)
df_2t['review2_len'] = df_2t['review2'].map(len)
df_2t.head(5)
# Out:
#                                               review label1  label2  \
# 0  지인이 추천해서 왔는데 시설도 깨끗하고 직원분들도 친절하네요^^아이와 왔는데 재밌는...     문화       1
# 1          완전좋아요\n가격이 꽤 나가서 일찍 가서 여유있게 놀다오는거\n추천드립니다     문화       1
# 2                               운동장에 눈이 있어 미끄러워 아쉽네요     문화       0
# 3               평소랑 다르게 오늘은 삐뚤삐뚤하게 삐죽 삐져나온게 너무많아요 ㅠ      미용       0
# 4  벌써 4번째 방문인데 오늘도 넘 만족스럽게 미용해주셨어여 귀가 넘 귀엽..♡제가 스...     미용       1
#
#                                              review2  review2_len
# 0  지인이 추천해서 왔는데 시설도 깨끗하고 직원분들도 친절하네요아이와 왔는데 재밌는 체...           62
# 1            완전좋아요 가격이 꽤 나가서 일찍 가서 여유있게 놀다오는거 추천드립니다           39
# 2                               운동장에 눈이 있어 미끄러워 아쉽네요           20
# 3               평소랑 다르게 오늘은 삐뚤삐뚤하게 삐죽 삐져나온게 너무많아요 ㅠ            36
# 4  벌써 번째 방문인데 오늘도 넘 만족스럽게 미용해주셨어여 귀가 넘 귀엽제가 스스로 쓰...          131

# %%
df_3t['review2'] = extract_korean_from_series(df_3t['review'])
df_3t.head(2)
df_3t['review2_len'] = df_3t['review2'].map(len)
df_3t.head(5)
# Out:
#                                               review label1  label2  \
# 0  챠슈카츠정식은 할라피뇨소스를 추가하시면 덜 느끼하게 먹기 좋아요 살짝 비린맛이나요닭...     퓨전       0
# 1                        사람이 많아요.주차장이 없어 유료 주차 해야해요.     퓨전       0
# 2  이중생업 맛없다 하는 사람도 있나요 진차 JMT💖데이트 장소로도 찰떡이구 .. 오후...     퓨전       1
# 3  음식도 맛있었고 분위기도 좋았는데 마감 때쯤 방문해서 아직 손님들이 밥 먹고 있는데...     퓨전       0
# 4  으앗 너무좁고 비좁고 첨엔맛있었는데 갈수록 느끼해져서 다못먹고 남겼어요 첨에딱먹을때...     퓨전       0
#
#                                              review2  review2_len
# 0  챠슈카츠정식은 할라피뇨소스를 추가하시면 덜 느끼하게 먹기 좋아요 살짝 비린맛이나요닭...           96
# 1                          사람이 많아요주차장이 없어 유료 주차 해야해요           25
# 2  이중생업 맛없다 하는 사람도 있나요 진차 데이트 장소로도 찰떡이구 오후에는 하이볼과...           71
# 3  음식도 맛있었고 분위기도 좋았는데 마감 때쯤 방문해서 아직 손님들이 밥 먹고 있는데...           85
# 4  으앗 너무좁고 비좁고 첨엔맛있었는데 갈수록 느끼해져서 다못먹고 남겼어요 첨에딱먹을때...           51

# %%
verb_adjective_1t = extract_adjectives_from_series_by_okt(okt, df_1t['review2'])
# Out:
# 1번째 수행.../ 소요시간 : 0.3620309829711914
# 2번째 수행.../ 소요시간 : 0.013962030410766602
# 3번째 수행.../ 소요시간 : 0.04937458038330078
# 4번째 수행.../ 소요시간 : 0.035904645919799805
# 5번째 수행.../ 소요시간 : 0.6477756500244141
# 6번째 수행.../ 소요시간 : 0.06283211708068848
# 7번째 수행.../ 소요시간 : 0.3166627883911133
# 8번째 수행.../ 소요시간 : 0.09175419807434082
# 9번째 수행.../ 소요시간 : 0.3201436996459961
# 10번째 수행.../ 소요시간 : 0.0413975715637207
# 11번째 수행.../ 소요시간 : 0.35956358909606934
# 12번째 수행.../ 소요시간 : 0.08776521682739258
# 13번째 수행.../ 소요시간 : 0.35405397415161133
# 14번째 수행.../ 소요시간 : 0.07878947257995605
# 15번째 수행.../ 소요시간 : 0.027924299240112305
# 16번째 수행.../ 소요시간 : 0.34059882164001465
# 17번째 수행.../ 소요시간 : 0.04587745666503906
# 18번째 수행.../ 소요시간 : 0.3720052242279053
# 19번째 수행.../ 소요시간 : 0.04587721824645996
# 20번째 수행.../ 소요시간 : 0.045877695083618164

# %%
verb_adjective_2t = extract_adjectives_from_series_by_okt(okt, df_2t['review2'])
# Out:
# 1번째 수행.../ 소요시간 : 0.00498652458190918
# 2번째 수행.../ 소요시간 : 0.00399017333984375
# 3번째 수행.../ 소요시간 : 0.0009987354278564453
# 4번째 수행.../ 소요시간 : 0.002989530563354492
# 5번째 수행.../ 소요시간 : 0.005493879318237305
# 6번째 수행.../ 소요시간 : 0.010972023010253906
# 7번째 수행.../ 소요시간 : 0.0009963512420654297
# 8번째 수행.../ 소요시간 : 0.0029914379119873047
# 9번째 수행.../ 소요시간 : 0.006982564926147461
# 10번째 수행.../ 소요시간 : 0.00897526741027832
# 11번째 수행.../ 소요시간 : 0.004987955093383789
# 12번째 수행.../ 소요시간 : 0.005982637405395508
# 13번째 수행.../ 소요시간 : 0.001993894577026367
# 14번째 수행.../ 소요시간 : 0.000997781753540039
# 15번째 수행.../ 소요시간 : 0.0009970664978027344
# 16번째 수행.../ 소요시간 : 0.008977651596069336
# 17번째 수행.../ 소요시간 : 0.0039882659912109375
# 18번째 수행.../ 소요시간 : 0.000997304916381836
# 19번째 수행.../ 소요시간 : 0.29871439933776855
# 20번째 수행.../ 소요시간 : 0.003989696502685547
# 21번째 수행.../ 소요시간 : 0.011966705322265625

# %%
verb_adjective_3t = extract_adjectives_from_series_by_okt(okt, df_3t['review2'])
# Out:
# 1번째 수행.../ 소요시간 : 0.009973526000976562
# 2번째 수행.../ 소요시간 : 0.000997304916381836
# 3번째 수행.../ 소요시간 : 0.003988981246948242
# 4번째 수행.../ 소요시간 : 0.0029921531677246094
# 5번째 수행.../ 소요시간 : 0.0019943714141845703
# 6번째 수행.../ 소요시간 : 0.001995563507080078
# 7번째 수행.../ 소요시간 : 0.007978677749633789
# 8번째 수행.../ 소요시간 : 0.003988504409790039
# 9번째 수행.../ 소요시간 : 0.0029935836791992188
# 10번째 수행.../ 소요시간 : 0.0059814453125
# 11번째 수행.../ 소요시간 : 0.0019948482513427734
# 12번째 수행.../ 소요시간 : 0.0019948482513427734
# 13번째 수행.../ 소요시간 : 0.0029916763305664062
# 14번째 수행.../ 소요시간 : 0.0029921531677246094
# 15번째 수행.../ 소요시간 : 0.0009975433349609375
# 16번째 수행.../ 소요시간 : 0.024933576583862305
# 17번째 수행.../ 소요시간 : 0.012965202331542969
# 18번째 수행.../ 소요시간 : 0.008976221084594727
# 19번째 수행.../ 소요시간 : 0.006981372833251953
# 20번째 수행.../ 소요시간 : 0.0029914379119873047
# 21번째 수행.../ 소요시간 : 0.00399017333984375
# 22번째 수행.../ 소요시간 : 0.005982875823974609
# 23번째 수행.../ 소요시간 : 0.0019948482513427734
# ...

# %%
verb_adjective_1t,verb_adjective_2t,verb_adjective_3t
# Out:
# ([['Adjective', '재미있겠는'],
#   ['Adjective', '그러고'],
#   ['Verb', '추워졌습니다'],
#   ['Verb', '잃고'],
#   ['Adjective', '빠르다더니'],
#   ['Verb', '지나서'],
#   ['Adjective', '힘드네요'],
#   ['Verb', '몰려'],
#   ['Verb', '갈게요'],
#   ['Verb', '쌓고'],
#   ['Verb', '어울린다'],
#   ['Verb', '그리'],
#   ['Verb', '했는데'],
#   ['Adjective', '어려웠다'],
#   ['Verb', '들어가시고'],
#   ['Adjective', '외롭지'],
#   ['Verb', '서며'],
#   ['Verb', '걸어야'],
#   ['Adjective', '많다'],
#   ['Verb', '가는길'],
#   ['Adjective', '흔하다'],
#   ['Adjective', '인해'],
#   ['Verb', '웃으며'],
#   ['Adjective', '힘듦이었'],
#   ['Verb', '닮았다'],
#   ['Adjective', '기대하기'],
#   ['Verb', '하고'],
#   ['Verb', '왔던'],
#   ['Verb', '놓여'],
#   ['Adjective', '똑같지만'],
#   ['Adjective', '없었음'],
#   ['Verb', '올라간다'],
#   ['Verb', '보러'],
#   ['Verb', '였는지'],
#   ['Verb', '지칠수'],
#   ['Verb', '타면'],
#   ['Verb', '다다른다'],
#   ['Verb', '늦은'],
#   ['Verb', '지었다'],
#   ['Verb', '막아'],
#   ['Adjective', '없으니'],
#   ['Verb', '않습니다'],
#   ['Verb', '오르기로'],
#   ['Verb', '하러'],
# ...

# %%
combined_array = np.vstack((verb_adjective_1t,verb_adjective_2t,verb_adjective_3t))
combined_array
# Out:
# array([['Adjective', '재미있겠는'],
#        ['Adjective', '그러고'],
#        ['Verb', '추워졌습니다'],
#        ...,
#        ['Verb', '주다니'],
#        ['Verb', '했어요'],
#        ['Adjective', '맛있어요']], dtype='<U9')

# %%
sentiment_dict = pd.DataFrame(combined_array,columns=['품사','단어'])
sentiment_dict = sentiment_dict.sort_values(by=['품사','단어'], ascending=[True,True])

# %%
sentiment_dict['품사'].value_counts()
# Out:
# 품사
# Verb         1357
# Adjective     753
# Name: count, dtype: int64

# %%
# 중복제거
sentiment_dict.drop_duplicates(ignore_index=True,inplace=True)

# %%
sentiment_dict.to_excel('./data/감성사전.xlsx',index=False)

# %%
# Out:
# False

# %%
sentiment_dict_1t = pd.DataFrame(verb_adjective_1t,columns=['품사','단어'])
sentiment_dict_1t = sentiment_dict_1t.sort_values(by=['품사','단어'], ascending=[True,True])
sentiment_dict_1t.drop_duplicates(ignore_index=True,inplace=True)
sentiment_dict_1t.to_excel('./data/감성사전_1t.xlsx',index=False)

# %%
sentiment_dict_2t = pd.DataFrame(verb_adjective_2t,columns=['품사','단어'])
sentiment_dict_2t = sentiment_dict_2t.sort_values(by=['품사','단어'], ascending=[True,True])
sentiment_dict_2t.drop_duplicates(ignore_index=True,inplace=True)
sentiment_dict_2t.to_excel('./data/감성사전_2t.xlsx',index=False)

# %%
sentiment_dict_3t = pd.DataFrame(verb_adjective_3t,columns=['품사','단어'])
sentiment_dict_3t = sentiment_dict_3t.sort_values(by=['품사','단어'], ascending=[True,True])
sentiment_dict_3t.drop_duplicates(ignore_index=True,inplace=True)
sentiment_dict_3t.to_excel('./data/감성사전_3t.xlsx',index=False)
