# %%
# !pip install koreanize_matplotlib
# Out:
# Collecting koreanize_matplotlib
#   Obtaining dependency information for koreanize_matplotlib from https://files.pythonhosted.org/packages/ef/91/93f56a4526d2dbead44250d9166d97568c2ce051c90eaa4be36788d59131/koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata
#   Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl.metadata (992 bytes)
# Requirement already satisfied: matplotlib in d:\kdt\anaconda3\lib\site-packages (from koreanize_matplotlib) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->koreanize_matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\kdt\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->koreanize_matplotlib) (1.16.0)
# Downloading koreanize_matplotlib-0.1.1-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.9 MB 495.5 kB/s eta 0:00:16
#    -- ------------------------------------- 0.6/7.9 MB 4.5 MB/s eta 0:00:02
#    ------------------ --------------------- 3.6/7.9 MB 21.1 MB/s eta 0:00:01
#    --------------------------- ------------ 5.4/7.9 MB 26.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.2/7.9 MB 24.9 MB/s eta 0:00:01
#    ---------------------------------------  7.9/7.9 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 25.4 MB/s eta 0:00:00
# Installing collected packages: koreanize_matplotlib
# Successfully installed koreanize_matplotlib-0.1.1

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in d:\kdt\anaconda3\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in d:\kdt\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in d:\kdt\anaconda3\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\kdt\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\kdt\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    ------- ------------------------------- 61.4/300.2 kB 812.7 kB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
plt.figure(figsize=(6,3))
plt.title('한글 테스트')
pd.Series([1,5,2,6,-3]).plot.bar()
# Out:
# <Axes: title={'center': '한글 테스트'}>

# %%
url = 'https://raw.githubusercontent.com/KLUE-benchmark/KLUE/main/klue_benchmark/ynat-v1.1/ynat-v1.1_train.json'
print(url)
df = pd.read_json(url)
df.shape
# Out:
# https://raw.githubusercontent.com/KLUE-benchmark/KLUE/main/klue_benchmark/ynat-v1.1/ynat-v1.1_train.json
# (45678, 7)

# %%
df.head(2)
# Out:
#                   guid                       title predefined_news_category  \
# 0  ynat-v1_train_00000  유튜브 내달 2일까지 크리에이터 지원 공간 운영                     IT과학
# 1  ynat-v1_train_00001     어버이날 맑다가 흐려져…남부지방 옅은 황사                     생활문화
#
#   label                                        annotations  \
# 0  생활문화  {'annotators': ['08', '13', '07'], 'annotation...
# 1  생활문화  {'annotators': ['14', '13', '07'], 'annotation...
#
#                                                  url                  date
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...  2016.06.30. 오전 10:36
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.05.08. 오전 5:25

# %%
# 제목 중복 체크
df.duplicated(subset=['title']).sum()
# Out:
# 0

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# guid                        0
# title                       0
# predefined_news_category    0
# label                       0
# annotations                 0
# url                         0
# date                        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45678 entries, 0 to 45677
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   guid                      45678 non-null  object
#  1   title                     45678 non-null  object
#  2   predefined_news_category  45678 non-null  object
#  3   label                     45678 non-null  object
#  4   annotations               45678 non-null  object
#  5   url                       45678 non-null  object
#  6   date                      45678 non-null  object
# dtypes: object(7)
# memory usage: 2.4+ MB

# %%
# 문장의 길이
df['title_len']=df['title'].str.len()
df.head(2)
# Out:
#                   guid                       title predefined_news_category  \
# 0  ynat-v1_train_00000  유튜브 내달 2일까지 크리에이터 지원 공간 운영                     IT과학
# 1  ynat-v1_train_00001     어버이날 맑다가 흐려져…남부지방 옅은 황사                     생활문화
#
#   label                                        annotations  \
# 0  생활문화  {'annotators': ['08', '13', '07'], 'annotation...
# 1  생활문화  {'annotators': ['14', '13', '07'], 'annotation...
#
#                                                  url                  date  \
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...  2016.06.30. 오전 10:36
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.05.08. 오전 5:25
#
#    title_len
# 0         26
# 1         23

# %%
# 토큰 갯수
df['title_count']=df['title'].str.split().str.len()
df.head(2)
# Out:
#                   guid                       title predefined_news_category  \
# 0  ynat-v1_train_00000  유튜브 내달 2일까지 크리에이터 지원 공간 운영                     IT과학
# 1  ynat-v1_train_00001     어버이날 맑다가 흐려져…남부지방 옅은 황사                     생활문화
#
#   label                                        annotations  \
# 0  생활문화  {'annotators': ['08', '13', '07'], 'annotation...
# 1  생활문화  {'annotators': ['14', '13', '07'], 'annotation...
#
#                                                  url                  date  \
# 0  https://news.naver.com/main/read.nhn?mode=LS2D...  2016.06.30. 오전 10:36
# 1  https://news.naver.com/main/read.nhn?mode=LS2D...   2016.05.08. 오전 5:25
#
#    title_len  title_count
# 0         26            7
# 1         23            5

# %%
df[['title_len','title_count']].describe()
# Out:
#           title_len   title_count
# count  45678.000000  45678.000000
# mean      27.366544      6.611213
# std        4.864236      1.460011
# min        4.000000      1.000000
# 25%       25.000000      6.000000
# 50%       28.000000      7.000000
# 75%       31.000000      8.000000
# max       44.000000     13.000000

# %%
df[df['title_len']==4]
# Out:
#                      guid title predefined_news_category label  \
# 4343  ynat-v1_train_04343  봄 산책                     생활문화  생활문화
#
#                                             annotations  \
# 4343  {'annotators': ['12', '10', '13'], 'annotation...
#
#                                                     url                 date  \
# 4343  https://news.naver.com/main/read.nhn?mode=LS2D...  2018.04.05. 오후 1:51
#
#       title_len  title_count
# 4343          4            2

# %%
df[['title_len','title_count']].hist(figsize=(6,3), bins=50)
# Out:
# array([[<Axes: title={'center': 'title_len'}>,
#         <Axes: title={'center': 'title_count'}>]], dtype=object)

# %%
# 제목이 가장 긴 제목 보기
df[df['title_len'] == df['title_len'].max()]
# Out:
#                       guid                                         title  \
# 5792   ynat-v1_train_05792  美기준금리 0.25%p 인상→0.50%∼0.75%…내년 3차례 인상 시사종합2보
# 20168  ynat-v1_train_20168  그래픽 네이처 세계 연구기관 2017년 평가 발표…서울대 국내 1위·세계 70위
# 28257  ynat-v1_train_28257  주말 N 여행 영남권 겨울바다 낭만…부산 갈맷길 1∼3코스 89.2㎞ 절경 즐비
# 30493  ynat-v1_train_30493  MWC 2018 갤S9 64GB 출고가 95만7천원…자급제 포함 28일 예약판매
#
#       predefined_news_category label  \
# 5792                        세계    세계
# 20168                     IT과학    사회
# 28257                     생활문화  생활문화
# 30493                     IT과학  IT과학
#
#                                              annotations  \
# 5792   {'annotators': ['02', '18', '03'], 'annotation...
# 20168  {'annotators': ['12', '07', '14'], 'annotation...
# 28257  {'annotators': ['14', '07', '15'], 'annotation...
# 30493  {'annotators': ['13', '10', '08'], 'annotation...
#
#                                                      url  \
# 5792   https://news.naver.com/main/read.nhn?mode=LS2D...
# 20168  https://news.naver.com/main/read.nhn?mode=LS2D...
# 28257  https://news.naver.com/main/read.nhn?mode=LS2D...
# 30493  https://news.naver.com/main/read.nhn?mode=LS2D...
#
#                        date  title_len  title_count
# 5792    2016.12.15. 오전 5:10         44            6
# 20168   2017.09.14. 오후 2:43         44           10
# 28257  2016.12.09. 오전 11:00         44           11
# 30493  2018.02.26. 오전 11:00         44            9

# %% [markdown]
# https://github.com/amueller/word_cloud

# %%
from wordcloud import WordCloud

# %%
font_path = r'c:\windows\Fonts\malgun.ttf'

# %%
stopwords = ['첫','의미','등']

def display_word_cloud(data,/,*,width=1200, height=500, stopwords=[],mask=None) :
    wordcloud = WordCloud(
        font_path=font_path,
        width=width,
        height=height,    
        random_state=2024,
        background_color='#000',
        stopwords=stopwords,  # 불용어 제거
        mask=mask,
        background_color=white
    ).generate(data)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()
    return wordcloud

# %%
# 제목컬럼 하나의 문자열로 만들기
news_title = " ".join(df['title'])
news_title[:200]
# Out:
# '유튜브 내달 2일까지 크리에이터 지원 공간 운영 어버이날 맑다가 흐려져…남부지방 옅은 황사 내년부터 국가RD 평가 때 논문건수는 반영 않는다 김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것 회색인간 작가 김동식 양심고백 등 새 소설집 2권 출간 야외서 생방송 하세요…액션캠 전용 요금제 잇따라 월드컵 태극전사 16강 전초기지 레오강 입성종합 미세먼지'

# %%
df['title_count'].sum()
# Out:
# 301987

# %%
 display_word_cloud(df['title'][3])

# %%
 display_word_cloud(news_title,width=2000, height=1000)

# %%
df['label'].unique()
# Out:
# array(['생활문화', '사회', 'IT과학', '스포츠', '세계', '정치', '경제'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# 세계      8320
# 스포츠     7742
# 정치      7379
# 경제      6118
# 생활문화    5751
# IT과학    5235
# 사회      5133
# Name: count, dtype: int64

# %%
subject_title = " ".join(   df.loc[ df['label'] == '세계', 'title' ])
subject_title[:200]
# Out:
# '왓츠앱稅 230원에 성난 레바논 민심…총리사퇴로 이어져종합2보 베트남 경제 고성장 지속…2분기 GDP 6.71% 성장 그리스서 한국전 참전 기념식…참전용사 한반도 평화 기원 美 베네수엘라 구호품 반입 촉구 안보리 결의 추진 파키스탄 경제난 속 카타르서 30억 달러 투자 유치 일본 예산팽창에 재정건전성 우려…내년에 장기채무 GDP 2배 칠레 민중가수 살해하고'

# %%
 display_word_cloud(subject_title,width=2000, height=1000)

# %%
subject_title2 = " ".join(   df.loc[ df['label'] == '생활문화', 'title' ])
subject_title2[:200]
# Out:
# '유튜브 내달 2일까지 크리에이터 지원 공간 운영 어버이날 맑다가 흐려져…남부지방 옅은 황사 회색인간 작가 김동식 양심고백 등 새 소설집 2권 출간 미세먼지 속 출근길 예스24 독자들이 선정한 올해의 책 여행의 이유 울산 오후 4시 건조주의보 디자인 역사의 기둥 100권의 잡지를 돌아보다 전국 곳곳에 저녁까지 비·강한 바람…낮 최고 27도 황사·미세먼지 기승'

# %%
 display_word_cloud(subject_title2,width=2000, height=1000)

# %%
# 정규표현식
# 숫자 제거 [0-9], \d, [^0-9], \D
# 문자만 남기기 [^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z]
#df['title'].str.replace('[0-9]', '', regex=True)
df['title2'] = df['title'].str.replace(r'\d','',regex=True)
df['title3'] = df['title'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣a-zA-Z]',' ',regex=True)
df['title4'] = df['title'].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣]',' ',regex=True)

# %%
df[['title','title2','title3','title4']].head()
# Out:
#                              title                           title2  \
# 0       유튜브 내달 2일까지 크리에이터 지원 공간 운영        유튜브 내달 일까지 크리에이터 지원 공간 운영
# 1          어버이날 맑다가 흐려져…남부지방 옅은 황사          어버이날 맑다가 흐려져…남부지방 옅은 황사
# 2      내년부터 국가RD 평가 때 논문건수는 반영 않는다      내년부터 국가RD 평가 때 논문건수는 반영 않는다
# 3  김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것  김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것
# 4   회색인간 작가 김동식 양심고백 등 새 소설집 2권 출간    회색인간 작가 김동식 양심고백 등 새 소설집 권 출간
#
#                             title3                           title4
# 0       유튜브 내달  일까지 크리에이터 지원 공간 운영       유튜브 내달  일까지 크리에이터 지원 공간 운영
# 1          어버이날 맑다가 흐려져 남부지방 옅은 황사          어버이날 맑다가 흐려져 남부지방 옅은 황사
# 2      내년부터 국가RD 평가 때 논문건수는 반영 않는다      내년부터 국가   평가 때 논문건수는 반영 않는다
# 3  김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것  김명자 신임 과총 회장 원로와 젊은 과학자 지혜 모을 것
# 4   회색인간 작가 김동식 양심고백 등 새 소설집  권 출간   회색인간 작가 김동식 양심고백 등 새 소설집  권 출간

# %%
 display_word_cloud(' '.join(df['title3']),width=2000, height=1000)

# %%
display_word_cloud(' '.join(df['title4']),width=2000, height=1000)

# %%
subject_title4 = " ".join(df.loc[df['label'] == '세계', 'title4'])
display_word_cloud(subject_title4,width=2000, height=1000)

# %% [markdown]
# ### 형태소 분석기로 특정 품사만 추출하기
# [hyunwoongko/pecab: Pecab: Pure python Korean morpheme analyzer based on Mecab](https://github.com/hyunwoongko/pecab)

# %%
# !pip install pecab
# Out:
# Collecting pecab
#   Downloading pecab-1.0.8.tar.gz (26.4 MB)
#      ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#      --------------------------------------- 0.0/26.4 MB 435.7 kB/s eta 0:01:01
#      ---------------------------------------- 0.1/26.4 MB 1.1 MB/s eta 0:00:25
#      - -------------------------------------- 1.1/26.4 MB 8.0 MB/s eta 0:00:04
#      ----- ---------------------------------- 3.4/26.4 MB 18.0 MB/s eta 0:00:02
#      -------- ------------------------------- 5.7/26.4 MB 24.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 7.8/26.4 MB 27.5 MB/s eta 0:00:01
#      -------------- ------------------------- 9.7/26.4 MB 29.6 MB/s eta 0:00:01
#      ----------------- --------------------- 11.8/26.4 MB 46.7 MB/s eta 0:00:01
#      -------------------- ------------------ 13.9/26.4 MB 43.5 MB/s eta 0:00:01
#      ----------------------- --------------- 15.7/26.4 MB 43.5 MB/s eta 0:00:01
#      ----------------------- --------------- 15.7/26.4 MB 43.5 MB/s eta 0:00:01
#      ----------------------- --------------- 15.7/26.4 MB 43.5 MB/s eta 0:00:01
#      ----------------------- --------------- 15.7/26.4 MB 43.5 MB/s eta 0:00:01
#      ----------------------- --------------- 15.7/26.4 MB 43.5 MB/s eta 0:00:01
#      ------------------------- ------------- 17.5/26.4 MB 23.4 MB/s eta 0:00:01
#      ---------------------------- ---------- 19.6/26.4 MB 24.2 MB/s eta 0:00:01
#      ------------------------------- ------- 21.6/26.4 MB 24.2 MB/s eta 0:00:01
#      ----------------------------------- --- 23.7/26.4 MB 24.2 MB/s eta 0:00:01
#      --------------------------------------  25.9/26.4 MB 24.2 MB/s eta 0:00:01
#      --------------------------------------  26.4/26.4 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------  26.4/26.4 MB 43.7 MB/s eta 0:00:01
#      --------------------------------------- 26.4/26.4 MB 31.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in d:\kdt\anaconda3\lib\site-packages (from pecab) (1.24.3)
# Requirement already satisfied: pyarrow in d:\kdt\anaconda3\lib\site-packages (from pecab) (11.0.0)
# Requirement already satisfied: regex in d:\kdt\anaconda3\lib\site-packages (from pecab) (2022.7.9)
# Collecting emoji==1.2.0 (from pecab)
#   Obtaining dependency information for emoji==1.2.0 from https://files.pythonhosted.org/packages/24/fa/b3368f41b95a286f8d300e323449ab4e86b85334c2e0b477e94422b8ed0f/emoji-1.2.0-py3-none-any.whl.metadata
#   Downloading emoji-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pytest in d:\kdt\anaconda3\lib\site-packages (from pecab) (7.4.0)
# Requirement already satisfied: iniconfig in d:\kdt\anaconda3\lib\site-packages (from pytest->pecab) (1.1.1)
# Requirement already satisfied: packaging in d:\kdt\anaconda3\lib\site-packages (from pytest->pecab) (23.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in d:\kdt\anaconda3\lib\site-packages (from pytest->pecab) (1.0.0)
# Requirement already satisfied: colorama in d:\kdt\anaconda3\lib\site-packages (from pytest->pecab) (0.4.6)
# Downloading emoji-1.2.0-py3-none-any.whl (131 kB)
#    ---------------------------------------- 0.0/131.3 kB ? eta -:--:--
#    ---------------------------------------- 131.3/131.3 kB 7.6 MB/s eta 0:00:00
# Building wheels for collected packages: pecab
#   Building wheel for pecab (setup.py): started
#   Building wheel for pecab (setup.py): finished with status 'done'
#   Created wheel for pecab: filename=pecab-1.0.8-py3-none-any.whl size=26646701 sha256=77505cd745012c292cf2a0b8ed6519470e5fe4bd2a31536dd99928b8f3607ba5
#   Stored in directory: c:\users\kh502\appdata\local\pip\cache\wheels\c9\0d\97\ca2bb361e44a80f4c63efe6f6438ff903fd1ab5640eedabc1b
# Successfully built pecab
# Installing collected packages: emoji, pecab
# Successfully installed emoji-1.2.0 pecab-1.0.8

# %%
# 가장 긴 제목 가져오기
df.loc[df['title_len'] == df['title_len'].max(), 'title']
# Out:
# 5792     美기준금리 0.25%p 인상→0.50%∼0.75%…내년 3차례 인상 시사종합2보
# 20168    그래픽 네이처 세계 연구기관 2017년 평가 발표…서울대 국내 1위·세계 70위
# 28257    주말 N 여행 영남권 겨울바다 낭만…부산 갈맷길 1∼3코스 89.2㎞ 절경 즐비
# 30493    MWC 2018 갤S9 64GB 출고가 95만7천원…자급제 포함 28일 예약판매
# Name: title, dtype: object

# %%
df.loc[20168,'title']
# Out:
# '그래픽 네이처 세계 연구기관 2017년 평가 발표…서울대 국내 1위·세계 70위'

# %%
from pecab import PeCab

# %%
pecab = PeCab()
pecab.nouns(df.loc[20168,'title'])
# Out:
# ['그래픽', '네이처', '세계', '연구', '기관', '년', '평가', '발표', '서울대', '국내', '위', '세계', '위']

# %%
# 사회 부문 기사제목 1000건 무작위 추출
df_society = df.loc[df['label'] == '사회'].sample(1000,random_state=2024).copy()
df_society.shape
# Out:
# (1000, 12)

# %%
# 시간이 오래 걸리는 작업시 시각적으로 진행상황 수치로( %) 보여준다.
from tqdm import tqdm
tqdm.pandas()

df_society['title_none'] = df_society['title'].progress_map(lambda x: ' '.join(pecab.nouns(x)))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:10<00:00, 93.90it/s]

# %%
df_society[['title','title2','title3','title4','title_none']].head()
# Out:
#                                   title                           title2  \
# 10524        송재 서재필 언론인상 제정 내달 7일 첫 시상식        송재 서재필 언론인상 제정 내달 일 첫 시상식
# 34438  중소기업 상생 힘쓴다…다음 달 네이버 커넥트 2017 개최     중소기업 상생 힘쓴다…다음 달 네이버 커넥트  개최
# 19087            5·18에 관한 5가지 미스터리에 답하다               ·에 관한 가지 미스터리에 답하다
# 31496   국립여성사전시관장 수많은 여성독립운동가 존재 알리고 싶다  국립여성사전시관장 수많은 여성독립운동가 존재 알리고 싶다
# 31290     佛 전동스쿠터 사망사고 잇따라…피해자들 규제강화 촉구    佛 전동스쿠터 사망사고 잇따라…피해자들 규제강화 촉구
#
#                                  title3                            title4  \
# 10524        송재 서재필 언론인상 제정 내달  일 첫 시상식        송재 서재필 언론인상 제정 내달  일 첫 시상식
# 34438  중소기업 상생 힘쓴다 다음 달 네이버 커넥트      개최  중소기업 상생 힘쓴다 다음 달 네이버 커넥트      개최
# 19087                에 관한  가지 미스터리에 답하다                에 관한  가지 미스터리에 답하다
# 31496   국립여성사전시관장 수많은 여성독립운동가 존재 알리고 싶다   국립여성사전시관장 수많은 여성독립운동가 존재 알리고 싶다
# 31290       전동스쿠터 사망사고 잇따라 피해자들 규제강화 촉구       전동스쿠터 사망사고 잇따라 피해자들 규제강화 촉구
#
#                         title_none
# 10524    송 재 서재필 언론 인상 제정 내달 일 시상식
# 34438     중소기업 상생 힘 다음 달 네이버 커넥트 개
# 19087                    가지 미스터리 답
# 31496    국립 여성 사 전시 관장 여성 독립운동가 존재
# 31290  佛 전동 스쿠터 사망 사고 피해자 규제 강화 촉구

# %%
stopwords = ['명','일','년','만','위','등','천','중','개']
wordcloud_society = display_word_cloud(' '.join(df_society['title_none']), stopwords=stopwords)

# %%
dir(wordcloud_society)
# Out:
# ['__array__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_generated',
#  '_draw_contour',
#  '_get_bolean_mask',
#  'background_color',
#  'collocation_threshold',
#  'collocations',
#  'color_func',
#  'colormap',
#  'contour_color',
#  'contour_width',
#  'fit_words',
#  'font_path',
#  'font_step',
#  'generate',
#  'generate_from_frequencies',
#  'generate_from_text',
#  'height',
#  'include_numbers',
#  'layout_',
#  'margin',
#  'mask',
#  'max_font_size',
#  'max_words',
#  'min_font_size',
#  'min_word_length',
#  'mode',
#  'normalize_plurals',
#  'prefer_horizontal',
#  'process_text',
#  'random_state',
#  'recolor',
#  'regexp',
#  'relative_scaling',
#  'repeat',
#  'scale',
#  'stopwords',
#  'to_array',
#  'to_file',
#  'to_image',
#  'to_svg',
#  'width',
#  'words_']

# %%
wordcloud_society.words_
# Out:
# {'종합': 1.0,
#  '한국': 0.64,
#  '게시판': 0.56,
#  '방송': 0.38666666666666666,
#  '사장': 0.30666666666666664,
#  '조사': 0.29333333333333333,
#  '검찰': 0.28,
#  '뉴스': 0.28,
#  '논란': 0.26666666666666666,
#  '대상': 0.26666666666666666,
#  '경찰': 0.25333333333333335,
#  '회장': 0.25333333333333335,
#  '언론': 0.22666666666666666,
#  '의혹': 0.22666666666666666,
#  '위원회': 0.22666666666666666,
#  '대표': 0.22666666666666666,
#  '정보': 0.22666666666666666,
#  '서울': 0.22666666666666666,
#  '네이버': 0.2,
#  '수사': 0.2,
#  '부산': 0.2,
#  '지역': 0.2,
#  '전': 0.2,
#  '선정': 0.18666666666666668,
#  '시장': 0.18666666666666668,
#  '원': 0.18666666666666668,
#  '지원': 0.18666666666666668,
#  '불법': 0.18666666666666668,
#  '정부': 0.18666666666666668,
#  '인터넷': 0.18666666666666668,
#  '개최': 0.18666666666666668,
#  '대': 0.18666666666666668,
#  '산업': 0.18666666666666668,
#  '방통': 0.17333333333333334,
#  '법': 0.17333333333333334,
#  '사': 0.16,
#  '사고': 0.16,
#  '영상': 0.16,
#  '공개': 0.16,
#  '주년': 0.16,
#  '세계': 0.16,
#  '연구': 0.16,
#  '기업': 0.16,
#  '가능': 0.16,
#  '건': 0.16,
#  '기자 협회': 0.16,
#  '규제': 0.14666666666666667,
#  '강화': 0.14666666666666667,
#  '협회': 0.14666666666666667,
#  '사건': 0.14666666666666667,
#  '직원': 0.14666666666666667,
#  '사회': 0.14666666666666667,
#  '요구': 0.14666666666666667,
#  '억': 0.14666666666666667,
#  '올해': 0.14666666666666667,
#  '억 원': 0.14666666666666667,
#  '행사': 0.13333333333333333,
#  '재단': 0.13333333333333333,
#  '관광객': 0.13333333333333333,
#  '제주': 0.13333333333333333,
#  '돋보기': 0.13333333333333333,
#  '보도': 0.13333333333333333,
#  '연합뉴스': 0.13333333333333333,
#  '활용': 0.13333333333333333,
#  '압수수색': 0.13333333333333333,
#  '인': 0.13333333333333333,
#  '기준': 0.13333333333333333,
#  '혁신': 0.13333333333333333,
#  '광고': 0.13333333333333333,
#  '간': 0.13333333333333333,
#  '국민': 0.13333333333333333,
#  '피해': 0.13333333333333333,
#  '서비스': 0.13333333333333333,
#  '대책': 0.13333333333333333,
#  '시간': 0.13333333333333333,
#  '추진': 0.13333333333333333,
#  '종합 보': 0.13333333333333333,
#  '상생': 0.12,
#  '촉구': 0.12,
#  '감사': 0.12,
#  '시': 0.12,
#  '관리': 0.12,
#  '부': 0.12,
#  '금융': 0.12,
#  '조치': 0.12,
#  '공무원': 0.12,
#  '발표': 0.12,
#  '모집': 0.12,
#  '차': 0.12,
#  '월': 0.12,
#  '공공': 0.12,
#  '신문': 0.12,
#  '대회': 0.12,
#  '구조': 0.12,
#  '증가': 0.12,
#  '평가': 0.12,
#  '청년': 0.12,
#  '검토': 0.12,
#  '정책': 0.12,
#  '공사': 0.12,
#  '천만 원': 0.12,
#  '미래 부': 0.12,
#  '여성': 0.10666666666666667,
#  '국내': 0.10666666666666667,
#  '통신': 0.10666666666666667,
#  '전북': 0.10666666666666667,
#  '장관': 0.10666666666666667,
#  '노조': 0.10666666666666667,
#  '대학': 0.10666666666666667,
#  '내일': 0.10666666666666667,
#  '기술': 0.10666666666666667,
#  '후': 0.10666666666666667,
#  '안전': 0.10666666666666667,
#  '사업': 0.10666666666666667,
#  '구성': 0.10666666666666667,
#  '기관': 0.10666666666666667,
#  '소송': 0.10666666666666667,
#  '구속': 0.10666666666666667,
#  '민주': 0.10666666666666667,
#  '개혁': 0.10666666666666667,
#  '계약': 0.10666666666666667,
#  '논의': 0.10666666666666667,
#  '대응': 0.10666666666666667,
#  '것': 0.10666666666666667,
#  '주택': 0.10666666666666667,
#  '제공': 0.10666666666666667,
#  '추천': 0.10666666666666667,
#  '공모': 0.10666666666666667,
#  '교수': 0.10666666666666667,
#  '지상파': 0.10666666666666667,
#  '사퇴': 0.10666666666666667,
#  '日': 0.09333333333333334,
#  '조직': 0.09333333333333334,
#  '문화': 0.09333333333333334,
#  '개선': 0.09333333333333334,
#  '방문': 0.09333333333333334,
#  '기자': 0.09333333333333334,
#  '카카오': 0.09333333333333334,
#  '접수': 0.09333333333333334,
#  '처벌': 0.09333333333333334,
#  '모바일': 0.09333333333333334,
#  '시민': 0.09333333333333334,
#  '후보': 0.09333333333333334,
#  '마련': 0.09333333333333334,
#  '전환': 0.09333333333333334,
#  '간담회': 0.09333333333333334,
#  '곳': 0.09333333333333334,
#  '대전': 0.09333333333333334,
#  '제작': 0.09333333333333334,
#  '회의': 0.09333333333333334,
#  '미래': 0.09333333333333334,
#  '위반': 0.09333333333333334,
#  '산불': 0.09333333333333334,
#  '번': 0.09333333333333334,
#  '글로벌': 0.09333333333333334,
#  '씨': 0.09333333333333334,
#  '장': 0.09333333333333334,
#  '최고': 0.09333333333333334,
#  '확대': 0.09333333333333334,
#  '현장': 0.09333333333333334,
#  '고객': 0.09333333333333334,
#  '인사': 0.09333333333333334,
#  '발': 0.09333333333333334,
#  '법원': 0.09333333333333334,
#  '폐지': 0.09333333333333334,
#  '조정': 0.09333333333333334,
#  '계획': 0.09333333333333334,
#  '작년': 0.09333333333333334,
#  '책임': 0.09333333333333334,
#  '인천': 0.09333333333333334,
#  '방송 통신': 0.09333333333333334,
#  '세월 호': 0.09333333333333334,
#  '사망': 0.08,
#  '특별': 0.08,
#  '사용': 0.08,
#  '기소': 0.08,
#  '보고서': 0.08,
#  '중심': 0.08,
#  '활동': 0.08,
#  '광주': 0.08,
#  '댓글': 0.08,
#  '금감원': 0.08,
#  '교육': 0.08,
#  '롯데': 0.08,
#  '그룹': 0.08,
#  '선임': 0.08,
#  '올림픽': 0.08,
#  '집': 0.08,
#  '테러': 0.08,
#  '지정': 0.08,
#  '공장': 0.08,
#  '정상': 0.08,
#  '나': 0.08,
#  '일자리': 0.08,
#  '세': 0.08,
#  '토론회': 0.08,
#  '외국인': 0.08,
#  '참여': 0.08,
#  '주요': 0.08,
#  '신규': 0.08}

# %%
plt.figure(figsize=(12,10))
wordcloud_society_s = pd.Series(wordcloud_society.words_)
wordcloud_society_s.nlargest(20).sort_values(ascending=True).plot.barh()
# Out:
# <Axes: >

# %%
import requests
from PIL import Image

mask_img_path = 'https://cdn.pixabay.com/photo/2016/04/01/08/48/architecture-1298980_1280.png'

# 이미지 다운로드
response = requests.get(mask_img_path)

# http요청이 성공적으로 수행됐으면 이미지를 로컬에 저장
if response.status_code == 200:
    with open('architecture-1298980_1280.png','wb') as file:
        file.write(response.content)

        
mask_img = np.array(Image.open('architecture-1298980_1280.png'))

# %%
print(mask_img_path)

# %%
mask_img.shape
# Out:
# (1280, 1215, 4)

# %%
stopwords = ['명','일','년','만','위','등','천','중','개']
wordcloud_society = display_word_cloud(' '.join(df_society['title_none']), stopwords=stopwords, mask=mask_img)
