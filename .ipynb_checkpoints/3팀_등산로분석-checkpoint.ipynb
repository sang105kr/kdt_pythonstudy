# %%
# 데이터 분석을 위해 pandas를, 수치계산을 위해 numpy를, 시각화를위해 mapplotlib,seaborn 를 불러온다
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 한글설정 & 마이너스표시
plt.rc('font',family='Malgun Gothic') 
plt.rc('axes',unicode_minus=False)

# %%
df = pd.read_csv('1_data.csv',encoding='cp949')
# Out:
# C:\Users\kh502\AppData\Local\Temp\ipykernel_15416\2734621014.py:1: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('1_data.csv',encoding='cp949')

# %%
df.shape
# Out:
# (57449, 18)

# %%
## 모든 열 보이게하기 설정
pd.set_option('display.max_columns', None)
## 모든 행 보이게하기 설정
# pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    UserID  UserID_1  PMNTN_SN  MNTN_CODE MNTN_NM PMNTN_NM PMNTN_MAIN  \
# 0       0         0     32553  428203804     소똥령    진부리구간        NaN
# 1       0         0     16474  428203704  머네골1구간    장신리구간        NaN
# 2       0         0      1955  428200301     건봉산    광산리구간        NaN
# 3       0         0     47554  428204404     진부령    진부리구간        NaN
# 4       0         0     36422  428203904    안흘리길    장신리구간        NaN
#
#    PMNTN_LT PMNTN_DFFL  PMNTN_UPPL  PMNTN_GODN PMNTN_MTRQ PMNTN_CNRL  \
# 0      2.53         쉬움          45          31        NaN        NaN
# 1      2.78         쉬움          49          34        NaN        NaN
# 2      6.18         쉬움         109          76        NaN        NaN
# 3      3.31         쉬움          58          41        NaN        NaN
# 4     10.31         쉬움         221         155        NaN        NaN
#
#   PMNTN_CLS_ PMNTN_RISK PMNTN_RECO  DATA_STDR_      MNTN_ID
# 0        NaN        NaN        NaN  2016-12-31  428201601.0
# 1          Y        NaN        NaN  2016-12-31  428201301.0
# 2          Y        NaN        NaN  2016-12-31  428200301.0
# 3        NaN        NaN        NaN  2016-12-31  428204404.0
# 4        NaN        NaN        NaN  2016-12-31  428201901.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57449 entries, 0 to 57448
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UserID      57449 non-null  int64
#  1   UserID_1    57449 non-null  int64
#  2   PMNTN_SN    57449 non-null  int64
#  3   MNTN_CODE   57449 non-null  int64
#  4   MNTN_NM     57449 non-null  object
#  5   PMNTN_NM    34293 non-null  object
#  6   PMNTN_MAIN  930 non-null    object
#  7   PMNTN_LT    57449 non-null  float64
#  8   PMNTN_DFFL  57375 non-null  object
#  9   PMNTN_UPPL  57449 non-null  int64
#  10  PMNTN_GODN  57449 non-null  int64
#  11  PMNTN_MTRQ  8988 non-null   object
#  12  PMNTN_CNRL  11 non-null     object
#  13  PMNTN_CLS_  723 non-null    object
#  14  PMNTN_RISK  3278 non-null   object
#  15  PMNTN_RECO  248 non-null    object
#  16  DATA_STDR_  57447 non-null  object
#  17  MNTN_ID     57374 non-null  float64
# dtypes: float64(2), int64(6), object(10)
# memory usage: 7.9+ MB

# %%
df.describe()
# Out:
#         UserID  UserID_1      PMNTN_SN     MNTN_CODE      PMNTN_LT  \
# count  57449.0   57449.0  57449.000000  5.744900e+04  57449.000000
# mean       0.0       0.0  28540.502776  3.801290e+08      0.622806
# std        0.0       0.0  16466.476821  1.113158e+08      1.807544
# min        0.0       0.0      1.000000  1.111001e+08      0.000000
# 25%        0.0       0.0  14297.000000  2.826002e+08      0.090000
# 50%        0.0       0.0  28595.000000  4.272004e+08      0.240000
# 75%        0.0       0.0  42747.000000  4.680019e+08      0.640000
# max        0.0       0.0  59023.000000  4.913030e+08    117.930000
#
#          PMNTN_UPPL    PMNTN_GODN       MNTN_ID
# count  57449.000000  57449.000000  5.737400e+04
# mean      12.555954      8.708472  1.024158e+09
# std       38.059060     26.668265  9.296710e+08
# min        0.000000      0.000000  1.111001e+08
# 25%        2.000000      1.000000  4.136022e+08
# 50%        4.000000      3.000000  4.689021e+08
# 75%       11.000000      8.000000  1.605270e+09
# max     2081.000000   1457.000000  2.902199e+09

# %%
df.describe(include='O')
# Out:
#        MNTN_NM PMNTN_NM PMNTN_MAIN PMNTN_DFFL PMNTN_MTRQ PMNTN_CNRL  \
# count    57449    34293        930      57375       8988         11
# unique    2191     4889        646          7        108          1
# top        보문산    홍은동구간   황령산레포츠공원         쉬움         토사          Y
# freq       965      255         20      56511       5631         11
#
#        PMNTN_CLS_               PMNTN_RISK PMNTN_RECO  DATA_STDR_
# count         723                     3278        248       57447
# unique          1                      191          2           2
# top             Y  정상에서 역촌근린공원 내려오는 코스 급경사          Y  2016-12-31
# freq          723                      309        237       57373

# %%
df['PMNTN_DFFL'].value_counts()
# Out:
# PMNTN_DFFL
# 쉬움      56511
# 중간        843
# 어려리구       10
# 어려동구        6
# 어려산         3
# 어려봉-        1
# 어려재         1
# Name: count, dtype: int64

# %%
df['PMNTN_RISK'].unique()
# Out:
# array([nan, '암석노출', '가파른 절벽을 끼고 있음, 부주의에 의한 추락위험이 있음', '늪', '하천/늪지대',
#        '야간에등산할수 없음', '하산할때 방향을 잃어버리기 쉽고 매우 가파름', '비등산로 입산시 안전시설 및 나무 뿌리',
#        '해안절벽', '가파른 암벽이 다수 노출', '경사지/암석노출',
#        '바닥에 수분이 없고, 바닥이 굳어있으며, 자갈모래가 석여있어 미끄러질 위험이있다.', '나뭇가지가 너무 무성함',
#        '관리를 전혀 하지 않아, 덩쿨 걸려 넘어질 위험이 많다.',
#        '사람들도 다니지 않는 것 같고, 풀들이 많이 자라있어서 등산하기 어렵다.',
#        '산을 오르는 각이 너무 높고, 미끄러질 위험이 있다.', '습기가 많아 미끄러질 위험이 많이있다',
#        '암석노출/급경사구간', '관리 부족으로 인하여 풀들이 너무 많이자라 걸려 넘어질 위험이 있음',
#        '덩쿨걸려넘어질위협이많음', '돌들이 많이있고, 각이 진곳이 있으니 조심히 올라가는 것이좋다.', '경사도가심함',
#        '부분적으로 산책로 폭 협소하며 낭떠러지 있음', '근계 암석노출,경사구간', '미끄럼 주의', '미끄럼주의',
#        '등산로의 형태가 없어 위험요소가 많음', '벌주의', '암석 및 미끄럼 주의', '정상부 바위 미끄럼/벌',
#        '암반지대가많음', '산이 완만하여 큰위험요소 없음', '암반과 토사로 이루어진 구간이 많아 미끄러짐 주의 해야함',
#        '정상아래 암반주의', '밤나무밭주위라 독충이나 독사에 주의', '표지판 설치', '맷돼지/뱀',
#        '관리가 안되있는 곳에 넝쿨이 있어 걸릴 위험이있다.', '대부분 돌로 이루어져 있는 산이라 위험하다',
#        '습진곳이므로 미끄러질 위험이 있어 조심하는게 좋다.', '각이 높이 진곳이고, 습기가 많아서 미끄러질 위험이 있다',
#        '뱀이 많이 서식함', '급경사', '미끄러짐/낙석주의', '뿌리노출', '급경사가 약간 있음',
#        '등산로 구간에 비탈과 암석이 있어 미끄럼 주의', '압벽조심', '등산로가 가파른 급경사로 오르내림',
#        '급경사지와, 낙엽이나 토사가 쌓여 미끄러운 구간이 간혹 있음',
#        '험노출이 많은 부분이 있으며 필히 등산시 전문 등산화 필요및 등산 장비착용. 산에 물이 귀하므로 물을 충분히 준비하여야 함',
#        '로프설치필요망', '암벽/미끄러움', '난간 설치필요', '암벽조심', '추락위험지역,암벽주의',
#        '멧돼지서식에따른 위험성있음', '멧돼지서식지', '산사태 구역과 암반주위의 추락위험', '뱀이나 각종 위해 조수',
#        '유해조수', '뱀', '해질녘군부대', '급경사및암석지대', '경사가 심하고 토사여서 미끄러워 조심해야함',
#        '수변산책길은 미끄러짐에 주의', '정상 부근이 암봉으로 이루어져 있어 눈.비 올때 낙상 주의',
#        '등산로의 경사도가 심하지 않지만 일부 구간은 마사와 돌로 안전(미끄러짐)에 주의.', '1개소 50m구간 로프 설치',
#        '개소구간', '암벽', '암벽,절벽,미끄러움', '미끄러움', '급경사/로프', '암석/로프', '암반/암벽',
#        '급경사/암벽', '로프설치요망', '군부대사격장', '암벽,미끄러짐주의', '계곡길바위미끄럼주의',
#        '급경사,바위,절벽주의', '급경사,절벽', '암벽주의', '비탈길조심', '암석, 미끄러움 주의',
#        '등반시 가무넝쿨이 다소있고 지반이 무너져내려 등산로폭이 좁은 구간이 있습니다', '뱀,벌',
#        '곳곳에 뿌리 노출이 심화되고 있음', '곳곳에 전선늘어짐/뿌리 노출이 심화되고 있음',
#        '곳곳에 계단,난간필요/뿌리 노출이 심화되고 있음', '급경사/곳곳에 뿌리 노출이 심화되고 있음',
#        '등산가능한숲길 없음', '금경사숲길', '숲길진입로가 거의없음.',
#        '현재 이용 가능한 숲길이 거의없고, 간헐적인 주민밭접근로 와 성묘길 만이 존재함', '현재등산불가',
#        '숲길시설이 전혀 없고 경작지 통과 지역이 많음',
#        '임도 이외의 구간 에 급경사, 및 자갈,바위 등으로 등산로 정비가 요구됨',
#        '기존숲길이없는트랙측량으로 대부분 숲길전경 및위험지역으로분류함', '고압송전탑', '급경사구간주의',
#        '하산시 급경사 주의', '급경사노선', '비탈사면',
#        '정상에서 병천 5리 방향(수협연수원) 약 700m 가파른 경사.', '노선 분기점 중 급경사 지점', '뱀/벌',
#        '급경사,낙상주의', '등산로상에 방치된 간벌목', '판암동 방향 하산길 계단 중의 요망', '독사,급경사',
#        '정상에서부터 하산하는 내리막(120m 정도) 급경사 주의 요망',
#        '정상 동쪽 조망점 아래부터 경사가 가파르고 길이 불분명하여 주의가 필요', '급경사 약 200m',
#        '4-5m 크기의 쓰러진 소나무가 숲길을 막고 있음', '일부 급경사 지역 서행',
#        '야생동물(멧돼지 가끔 무리지어 나타남)', '계단.난간 필요/곳곳에 뿌리 노출이 심화되고 있음',
#        '정상에서 하산시 급경사지 주의요망',
#        '경사가 가파른 곳이 다수 산재되어 있고, 간벌후 잡목이 등산로 상에 방치 되어있음',
#        '정상에서 방아실 방향 100m 지점에서부터 두군데 급경사로 로프(또는 계단설치) 요망',
#        '숲길과 암벽의 경사가 가파르고 거칠어 미끄럼 주의', '자연돌출암', '급경사 1개소(할딱고개) 있으니 주의 필요함',
#        '경사심함', '계단,로프필요', '암반노출과 뿌리노출로 약간의 위험성이 있음', '하산시미끄러짐주의',
#        '급경사로 미끄러지기 쉬움', '다리시설필요', '암석산으로전구간위험',
#        '능선 중간 중간의 절벽구간 주의, 뱀과 벌,멧돼지등의 야생동물 주의',
#        '암반지역(미끄럼 주의), 야생조수(멧돼지, 독사), 등산로 유실, 겨울철 아이젠 필요',
#        '야생조수(멧돼지, 독사), 등산로 유실, 겨울철 아이젠 필요', '이정표가없어길찾기가어려움', '경찰학교사격장',
#        '궁도장 옆면으로 폐쇄', '군사보호시설', '미끄러짐주의',
#        '경사가 급하고 길의 폭이 좁으며 자갈이 많아 미끄러지기 쉬워 위험한 길이다',
#        '암석이 특히 많고 경사가  급해 내려가는 길이 매우 위험하다. WP23에서 아래로 내려가는 분기 3군데 모두 암석이 많고 경사가 급해 위험함',
#        '암석이 특히 많고 경사가  급해 내려가는 길이 매우 위험하다 WP23에서 아래로 내려가는 분기 3군데 모두 암석이 많고 경사가 급해 위험함',
#        '자갈이 많고 경사가 급해 내려가기 매우 위험함', '한국전력', '가파른낭떠러지',
#        '순환구간에는 차량이 다니므로 조심', '공사지역', '태양산 등산로는 등산객이 자주 다니지 않아서 매우 험함',
#        '암석노출,바위노출', '북쪽~동쪽으로 절벽길', '철조망 설치되어 위험함', '급경사가 많음  암석지대위험',
#        '전체적으로 완만한 산세지만 견사가 급해서 나무 계단을 만들어 놓은 곳이 있음',
#        '정상에서 역촌근린공원 내려오는 코스 급경사', '절벽지역',
#        '너무 가파르고 계단 설치한 것에 발이 걸릴 위험 있으니 차라리 폐쇄하는 게 나을 것 같음', '암벽지역',
#        '정상의 서남족 바위벼랑 주변에는 난간이나 밧줄 필요', '현통사 입구계곡 다리건너 암반 오를때 주의',
#        '암벽과 마사토라 하산코스는 매우 위험,경고 표지 필요함', '마사토와 암반 지역이 많아 미끄러질 위험이 있음',
#        '형제봉에서 앵무봉 가는 길에 군부대가 있어서 더 이상의 등산이 불가능하다', '경사가 심해 로프를 이용하여 등반',
#        '태재고개 부근 공사 현장 주의 필요', '사람들이 많이 다니지 않고 이정표가 잘 설치 되어 있지 않다',
#        '경사도가 심해 등산시 주의 요망', '부분적 암석 노출', '암반지대 좌우에 경사가심하며 미끄러움',
#        '좌측에 뿌리노출/낙석 위험지역', '경사가 가파르고 미끄러움', '암석코스 추락위험', '훼손된 산책로 및 절개지',
#        '일부 암석노출, 급경사', '멧돼지출몰', '위험하지않으나 주의가필요함',
#        '낙엽이 많아 등산로가 미끄럽고,지속적인 관리를 요함', '급경사구간', '강과매우인접', '미끄럼주의,암벽주위',
#        '급경사지역', '안전 시설물들이 대부분 임시적이고 경사가 다소 있음', '가파른길', '급경사바위지역',
#        '낭떠러지주의', '등산로 상단부에는 등산로가 좁고 소나무낙옆과 작은 자갈조각으로 미끄러질 우려가 있음',
#        '소로길의 노선침하나 작은계곡을 거널때 미끄럼주의', '암반지대가 많음/미끄럼주의',
#        '등산로에 낙엽이 많이 쌓여 미끄러질 위험이 있음',
#        '급경사 낭떠러지 구간 주의,뱀,멧돼지등의 야생동물,초행자는 길을 잃지 않도록 주의', '경사가 매우 급함',
#        '낙석지대와 암석지대가 분포하여 구간구간이 위험함'], dtype=object)

# %%
pd.set_option('display.max_rows', 60)
df['PMNTN_MTRQ'].value_counts()
# Out:
# PMNTN_MTRQ
# 토사             5631
# 흙길              898
# 토사/암반           498
# 마사토             155
# 토사/사력층          148
#                ...
# 토사/아스팔트/시멘트       1
# 흙                 1
# 토사/목계단            1
# 암반/미사             1
# 토양,암석             1
# Name: count, Length: 108, dtype: int64

# %%
# 결측치 확인
df.isnull().sum().sort_values(ascending=False)
# Out:
# PMNTN_CNRL    57438
# PMNTN_RECO    57201
# PMNTN_CLS_    56726
# PMNTN_MAIN    56519
# PMNTN_RISK    54171
# PMNTN_MTRQ    48461
# PMNTN_NM      23156
# MNTN_ID          75
# PMNTN_DFFL       74
# DATA_STDR_        2
# UserID            0
# PMNTN_GODN        0
# UserID_1          0
# PMNTN_LT          0
# MNTN_NM           0
# MNTN_CODE         0
# PMNTN_SN          0
# PMNTN_UPPL        0
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=True).plot.barh()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,20))
df['PMNTN_MTRQ'].value_counts().sort_values(ascending=True).plot.barh()
# Out:
# <Axes: ylabel='PMNTN_MTRQ'>

# %%
# 결측치를 다른 값으로 대체하기
# 등산로 통제 결측치 대체
df['PMNTN_CNRL'].fillna('N',inplace=True)
df['PMNTN_CNRL'].isnull().sum()
# 등산로 추천 결측치 대체
df['PMNTN_RECO'].fillna('M',inplace=True) # 중립
df['PMNTN_RECO'].isnull().sum()
# 폐쇄여부 격측치 대체
df['PMNTN_CLS_'].fillna('N',inplace=True) # 
df['PMNTN_CLS_'].isnull().sum()
# 위험요소 격측치 대체
df['PMNTN_RISK'].fillna('N',inplace=True) # 
df['PMNTN_RISK'].isnull().sum()
# Out:
# 0

# %%
df['PMNTN_NM'].isnull().sum()
# Out:
# 23156

# %%
# 등산로 이름 결측치 제거
print(df.shape)
df.dropna(subset=['PMNTN_NM'],inplace=True)
print(df.shape)
# Out:
# (57449, 18)
# (34293, 18)

# %%
# 이상치
plt.boxplot(df[['PMNTN_UPPL','PMNTN_GODN']])
plt.show()
