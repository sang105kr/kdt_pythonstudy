# %%
# http요청,응답 수행
import requests
# html문서 파싱 (DOM 요소 다루듯 쉽게 접근하는 기능 제공)
from bs4 import BeautifulSoup
# 정규표현식
import re
# 
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 폰트설정
plt.rc("font", family='Malgun Gothic')

# 마이너스폰트 설정
plt.rc("axes", unicode_minus=False)

# %%
# http요청
url = 'https://cc.naver.com/cc?a=new.real&r=&i=&bw=827&px=67&py=183&sx=67&sy=183&m=1&nsc=finance.news&u=https://finance.naver.com/news/news_list.naver?mode=LSS2D&section_id=101&section_id2=258&page=2'
headers = {
    'User-Agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
}
params = {}
res = requests.get(url,headers=headers, params=params)
res.status_code
# Out:
# 200

# %%
html = BeautifulSoup(res.text,'html.parser')
html
# Out:
# <!--  global include -->
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title">
# <meta content="http://finance.naver.com/news/news_list.naver?mode=LSS2D§ion_id=101§ion_id2=258&amp;type=0" property="og:url">
# <meta content="실시간 속보 : 네이버페이 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/finance_header.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/newstock.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/layout.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/main.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/newstock2.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/css/world.css" rel="stylesheet" type="text/css"/>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/js/release/common.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240313183844/js/nhn.autocomplete.stock.js" type="text/javascript"></script>
# <script>
# 	var ieVersion = (function () {
#         var version = -1;
#         if (
#           navigator.appName == 'Microsoft Internet Explorer' &&
#           navigator.userAgent.toLowerCase().indexOf('msie') != -1 &&
#           new RegExp('MSIE ([0-9]{1,}[\./0-9]{0,})').exec(navigator.userAgent) != null
#         ) {
#           version = parseInt(RegExp.$1);
#         }
#         return version;
#       })();
# </script>
# <!-- smart channel 광고 -->
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
# </script>
# <script type="text/javascript">
# 		(function(){
# 			if (ieVersion === -1 || ieVersion > 10) {
# 				window.gladsdk = window.gladsdk || { cmd: [] };
#
# 				gladsdk.cmd.push(function() {
# 						gladsdk.defineAdSlot({
# 							adUnitId: "p_new_stock",
# 							adSlotElementId: "_SmartChannelTopBanner",
# 							uct: "KR",
# 							customParam: {
# 								calp:
#
#
#
#
# 									"news"
#
#
# 							},
# 						});
#
#
#
# 						gladsdk.addEventListener(gladsdk.event.AD_LOADED, function(ad) {
# 							//console.log(gladsdk.event.AD_LOADED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_CLICKED, function(ad) {
# 							//console.log(gladsdk.event.AD_CLICKED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_IMPRESSED, function(ad) {
# 							//console.log(gladsdk.event.AD_IMPRESSED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.ERROR, function(ad, error) {
# 							//TODO: 오류 로깅처리
# 							//console.log(gladsdk.event.ERROR);
# 						});
# 					});
# 			}
# 		})();
# 	</script>
# <link href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
#     (function(){
# 		document.write(
# 				[
# 					'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>',
# 					'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x16.png"/>',
# 					'<link rel="icon" type="image/png" sizes="32x32" href="https://ssl.pstatic.net/imgstock/favi/favicon-32x32.png"/>',
# 					'<link rel="icon" type="image/png" sizes="96x96" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="icon" type="image/png" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>'
# 				]
# 			.join('\n')
# 		);
#     })();
#     </script>
# </meta></meta></head>
# <body onload="getGNB();">
# <script type="text/javascript">
# 	var nclk_evt = 3;
# 	nclk_do();
# </script>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var nsc="finance.news";
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
# </script>
# <div id="u_skip">
# <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#start" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header">
# <div class="header_area">
# <div class="header_inner">
# <div class="logo_area">
# <h1 class="service">
# <a class="logo_link" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 22 22" width="22" xmlns="http://www.w3.org/2000/svg">
# <path d="M22 11C22 13.1756 21.3549 15.3023 20.1462 17.1113C18.9375 18.9202 17.2195 20.3301 15.2095 21.1627C13.1995 21.9952 10.9878 22.2131 8.85401 21.7886C6.72022 21.3642 4.76021 20.3166 3.22183 18.7782C1.68345 17.2398 0.635805 15.2798 0.211368 13.146C-0.213069 11.0122 0.00476298 8.80047 0.837327 6.79048C1.66989 4.78049 3.07979 3.06253 4.88873 1.85383C6.69768 0.645137 8.82441 0 11 0C13.9174 0 16.7153 1.15893 18.7782 3.22183C20.8411 5.28473 22 8.08262 22 11ZM12.8398 5.83V11.3602L8.98976 5.83H5.83V16.1838H9.1575V10.637L13.0075 16.17H16.1783V5.83H12.8398Z" fill="#000"></path>
# </svg>
# <span class="blind">네이버</span>
# </a>
# <a class="logo_link" href="https://new-m.pay.naver.com/" onclick="clickcr(this, 'STA.pay', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 37 22" width="37" xmlns="http://www.w3.org/2000/svg">
# <path d="M34.4319 5.21944L31.3913 12.1478L27.9518 5.21944H25.3072L30.1783 14.8317L28.1703 19.3358H30.7384L37 5.2331L34.4319 5.21944ZM23.6171 15.9331H21.1037V14.9328C20.1894 15.7342 19.0108 16.1685 17.7953 16.1518C14.7901 16.1518 12.4379 13.692 12.4379 10.5763C12.4379 7.46057 14.7874 5.00079 17.7953 5.00079C19.0104 4.9833 20.189 5.41657 21.1037 6.21701V5.21944H23.6171V15.9331ZM21.3987 10.5899C21.3987 8.57019 19.9891 7.03694 18.1204 7.03694C16.2517 7.03694 14.842 8.57019 14.842 10.5899C14.842 12.6097 16.249 14.1429 18.1204 14.1429C19.9918 14.1429 21.3987 12.596 21.3987 10.5899ZM0.00819554 19.3358H2.63088V15.023C3.52823 15.7695 4.66309 16.1699 5.83001 16.1518C8.83516 16.1518 11.1901 13.692 11.1901 10.5763C11.1901 7.46057 8.83789 5.00079 5.83001 5.00079C4.61166 4.9789 3.42899 5.4126 2.51341 6.21701V5.21944H0L0.00819554 19.3358ZM5.51856 7.03694C7.38722 7.03694 8.79691 8.57019 8.79691 10.5899C8.79691 12.6097 7.38722 14.1429 5.51856 14.1429C3.6499 14.1429 2.24021 12.6097 2.24021 10.5899C2.24021 8.57019 3.63351 7.03694 5.51856 7.03694Z" fill="#000"></path>
# </svg>
# <span class="blind">페이</span>
# </a>
# <a class="logo_link" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 34 22" width="34" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.43006 8.88998L1.85406 6.99998C5.29206 6.31598 7.00206 5.34398 7.45206 4.31798H2.71806V2.35598H14.3641V4.31798H9.75606C9.70206 4.65998 9.61206 4.98398 9.46806 5.28998L15.2101 6.98198L14.4901 8.88998L8.02806 6.92798C6.84006 7.75598 5.00406 8.40398 2.43006 8.88998ZM0.612061 11.5V9.53798H16.4521V11.5H0.612061ZM6.53406 12.796H10.5301C13.2301 12.796 14.7961 14.128 14.7961 15.91C14.7961 17.71 13.2301 19.024 10.5301 19.024H6.53406C3.85206 19.024 2.28606 17.71 2.28606 15.91C2.28606 14.128 3.85206 12.796 6.53406 12.796ZM6.96606 17.044H10.1161C11.7901 17.044 12.4921 16.594 12.4921 15.892C12.4921 15.19 11.7901 14.776 10.1161 14.776H6.96606C5.29206 14.776 4.57206 15.19 4.57206 15.892C4.57206 16.594 5.29206 17.044 6.96606 17.044Z" fill="#000"></path>
# <path d="M25.1904 13.354V11.536H29.4564V2.03198H31.7604V15.334H29.4564V13.354H25.1904ZM21.3384 10.564C20.9244 10.582 20.5464 10.582 20.1684 10.582H17.4504L17.3604 8.61998H20.3844C21.5004 8.61998 22.9584 8.56598 24.4884 8.45798C24.7224 6.99998 24.8484 5.63198 24.8664 4.62398H18.4404V2.66198H27.0984V3.56198C27.0984 5.16398 26.9724 6.76598 26.7564 8.25998L28.2684 8.09798L28.5024 10.006C26.9724 10.222 25.2264 10.384 23.5704 10.474C23.4984 11.5 23.3904 12.562 23.2644 13.714L21.0684 13.588C21.1764 12.508 21.2664 11.536 21.3384 10.564ZM22.4724 14.254V16.756H32.3724V18.844H20.1684V14.254H22.4724Z" fill="#000"></path>
# </svg>
# <span class="blind">증권</span>
# </a>
# </h1>
# </div>
# <div class="right_area">
# <div class="search_area">
# <form action="/search/search.naver" method="get" name="search" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
# <label class="blind" for="stock_items">증권 종목명·지수명 검색</label>
# <input accesskey="s" autocomplete="off" class="search_input" id="stock_items" name="query" placeholder="종목명·지수명 입력" title="종목명·지수명 검색" type="text"/>
# <input id="_endUrl" name="endUrl" type="hidden" value="">
# <button class="search_button" onclick="clickcr(this, 'STA.search', '', '', event);" type="button">
# <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M6.9999 2.59996C4.56985 2.59996 2.5999 4.56991 2.5999 6.99996C2.5999 9.43002 4.56985 11.4 6.9999 11.4C9.42996 11.4 11.3999 9.43002 11.3999 6.99996C11.3999 4.56991 9.42996 2.59996 6.9999 2.59996ZM1.3999 6.99996C1.3999 3.90717 3.90711 1.39996 6.9999 1.39996C10.0927 1.39996 12.5999 3.90717 12.5999 6.99996C12.5999 10.0928 10.0927 12.6 6.9999 12.6C3.90711 12.6 1.3999 10.0928 1.3999 6.99996Z" fill="#404048" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M10.2421 10.2424C10.4765 10.0081 10.8564 10.0081 11.0907 10.2424L14.424 13.5758C14.6583 13.8101 14.6583 14.19 14.424 14.4243C14.1897 14.6586 13.8098 14.6586 13.5755 14.4243L10.2421 11.091C10.0078 10.8567 10.0078 10.4768 10.2421 10.2424Z" fill="#404048" fill-rule="evenodd"></path>
# </svg>
# <span class="blind">검색</span>
# </button>
# <div class="auto_area">
# <span class="blind">자동완성</span>
# <div id="autoFrame" style="display: none;">
# <div class="wrap" id="atcmp" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <ul class="_resultBox">
# <li>
# <a class="_au_real_list" href="#" onclick="clickcr(this, 'AUT.list', '', '', event); return false;">
# <span class="num _au_real_list">@code@</span>
# <span class="_au_real_list">@txt@</span>
# <span class="type _au_real_list">@market@</span>
# </a>
# <div class="_au_full" style="display:none">@full_txt@</div>
# <div class="_au_code" style="display:none">@in_code@</div>
# <div class="_au_name" style="display:none">@in_name@</div>
# <div class="_au_link" style="display:none">@in_link@</div>
# <div class="_au_market" style="display:none">@in_market@</div>
# </li>
# </ul>
# </div>
# </div>
# <!-- 현재 자동완성 기능을 사용하고 계십니다 -->
# <div class="wrap" id="atcmpIng" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												현재 자동완성 기능을 사용하고 계십니다.
# 											</p>
# </div>
# </div>
# </div>
# <!--// 현재 자동완성 기능을 사용하고 계십니다 -->
# <!-- 자동완성 기능이 활성화 -->
# <div class="wrap" id="atcmpStart" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												자동완성 기능이 활성화되었습니다.
# 											</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </input></form>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="EUC-KR" type="text/javascript">
# 							var gnb_service = "finance";
# 							var gnb_template = location.protocol === "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 							var gnb_logout=encodeURIComponent(location.href);
# 							var gnb_brightness = 1;
# 							var gnb_one_naver = 0;
# 						</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20240402" type="text/javascript">
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div id="menu">
# <ul class="menu">
# <li class="m1 first"><a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);"><span class="tx">증권 홈</span></a></li>
# <li class="m2"><a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);"><span class="tx">국내증시</span></a></li>
# <li class="m3"><a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);"><span class="tx">해외증시</span></a></li>
# <li class="m4"><a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);"><span class="tx">시장지표</span></a></li>
# <li class="m6"><a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);"><span class="tx">리서치</span></a></li>
# <li class="m7 on"><a href="/news/"><span class="tx">뉴스</span><span class="blind">선택됨</span></a></li>
# <li class="m8"><a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);"><span class="tx">MY</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/JavaScript">
# 		/* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.stock.naver.com";
#         if (location.hostname.indexOf("staging-") > -1) {
#             acDomain = "staging-" + acDomain;
#         } else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("localhost") > -1 || location.hostname.indexOf("local-") > -1) {
# 			acDomain = "dev-" + acDomain;
# 		}
#
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "xhr", "get", {}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl : [
# 										"https://" + window.location.hostname,
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"]}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock_disable"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		var sSearchHintText = '종목명·지수명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = location.protocol + "//search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object)
# 		{
# 			// endUrl check
# 			if (object.endUrl.value) {
# 				location.href = object.endUrl.value;
# 				return;
# 			}
#
# 			// query check
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
# 	</script>
# <iframe frameborder="0" height="0" id="me_layers" name="test" scrolling="no" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;" title="네이버미 영역" width="0"></iframe>
# </div>
# <div id="wrap">
# <!-- //  global include -->
# <div class="_replaceNewsLink" id="newarea">
# <!-- leftmenu -->
# <div class="snb snb2 snb3">
# <h2 class="h_news"><a href="/news/" onclick="clickcr(this, 'new.news', '', '', event)"><span class="blind">뉴스</span></a></h2>
# <ul class="nav1">
# <li class="frst"><a href="/news/news_list.naver?mode=LSS2D§ion_id=101§ion_id2=258" onclick="clickcr(this, 'new.real', '', '', event)"><strong class="other2 lst_news"><span class="blind">실시간속보</span></strong></a></li>
# <li><a href="/news/mainnews.naver" onclick="clickcr(this, 'new.main', '', '', event)"><strong class="other2 lst_news2"><span class="blind">주요뉴스</span></strong></a></li>
# <li class="another"><strong class="news_focus"><span class="blind">뉴스 포커스</span></strong>
# <ul class="sub">
# <li class="lst3_1"><a class="off" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=401" onclick="clickcr(this, 'new.fore', '', '', event)"><span class="blind">시황·전망</span></a></li>
# <li class="lst3_2"><a class="off" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=402" onclick="clickcr(this, 'new.firm', '', '', event)"><span class="blind">기업·종목분석</span></a></li>
# <li class="lst3_3"><a class="off" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=403" onclick="clickcr(this, 'new.aboard', '', '', event)"><span class="blind">해외증시</span></a></li>
# <li class="lst3_4"><a class="off" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=404" onclick="clickcr(this, 'new.bond', '', '', event)"><span class="blind">채권·선물</span></a></li>
# <li class="lst3_5"><a class="off" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=406" onclick="clickcr(this, 'new.memo', '', '', event)"><span class="blind">공시·메모</span></a></li>
# <li class="lst3_6"><a class="off" href="/news/news_list.naver?mode=LSS3D§ion_id=101§ion_id2=258§ion_id3=429" onclick="clickcr(this, 'new.currency', '', '', event)"><span class="blind">환율</span></a></li>
# </ul>
# </li>
# <li><a href="/news/news_list.naver?mode=RANK" onclick="clickcr(this, 'new.best', '', '', event)"><strong class="other2 lst_news5"><span class="blind">많이 본 뉴스</span></strong></a></li>
# <li><a href="/news/news_list.naver?mode=LSTD§ion_id=101§ion_id2=258&amp;type=1" onclick="clickcr(this, 'new.photo', '', '', event)"><strong class="other2 lst_news6"><span class="blind">포토뉴스</span></strong></a></li>
# <li><a href="/news/news_list.naver?mode=TV§ion_id=tv" onclick="clickcr(this, 'new.tv', '', '', event)"><strong class="other2 lst_news7"><span class="blind">TV뉴스</span></strong></a></li>
# <li class="another"><strong class="invest_info"><span class="blind">투자정보</span></strong>
# <ul class="sub">
# <li class="lst3_7"><a class="off" href="/news/market_notice.naver" onclick="clickcr(this, 'new.info', '', '', event)"><span class="blind">공시정보</span></a></li>
# </ul>
# </li>
# <li><a href="http://www.seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/company/BIP_CNTS01020V.xml&amp;menuNo=273" onclick="clickcr(this, 'new.sch', '', '', event)" target="_blank"><strong class="other2 lst_news8"><span class="blind">증시일정</span></strong></a></li>
# <li><a href="/news/news_search.naver" onclick="clickcr(this, 'new.search', '', '', event)"><strong class="other2 lst_news9"><span class="blind">뉴스검색</span></strong></a></li>
# </ul>
# <span class="nav1_blank"></span>
# <!-- 끼워넣기 -->
# <!--  여러개가 뉴스홈 배너로 등록되었을 경우에는 하나의 경우만 뿌려주게 한다. -->
# <div class="section_news">
# <h4 class="subtlt">
# <a href="https://finance.naver.com/news/news_search.naver?rcdate=&amp;q=%BF%C0%B4%C3%C0%C7+%C1%F5%BD%C3%C0%CF%C1%A4&amp;sm=title.basic&amp;pd=1&amp;stDateStart=" onclick="clickcr(this, 'new.todaytit', '', '', event)">뉴스로 보는 증시일정</a>
# </h4>
# <ul class="sub1">
# <li>
# <a href="https://finance.naver.com/news/news_search.naver?rcdate=&amp;q=%BF%C0%B4%C3%C0%C7+%C1%F5%BD%C3%C0%CF%C1%A4&amp;sm=title.basic&amp;pd=1&amp;stDateStart=" onclick="clickcr(this, 'new.today', '', '', event)">오늘의 증시일정</a>
# </li>
# </ul>
# </div>
# <!-- //끼워넣기 -->
# </div>
# <!-- //leftmenu -->
# <div id="contentarea">
# <!-- 컨텐츠 -->
# <div id="contentarea_left">
# <!-- 로케이터 -->
# <div class="sub_location tlt_bottom_line">
# <a href="/">증권홈</a> &gt; <a href="/news/">뉴스</a> &gt; 실시간 속보
# 				</div>
# <!-- //로케이터 -->
# <h3 class="sub_tlt">실시간 속보</h3>
# <!-- 타이틀 우측 티커 영역 -->
# <script type="text/javascript">
# 	var newsflash_rcnt_gno = newsflash_rcnt_gno_max = 10;
# 	var newsflash_rolling_tag = 1;
# 	function view_newsflash(mode)
# 	{
# 		var total = 10;
# 		var gcnt = 1;
# 		var li_name;
# 		var start, end;
#
# 		if (mode == 'next') 			newsflash_rcnt_gno++;
# 		else if (mode == 'prev') 	newsflash_rcnt_gno--;
# 		newsflash_rcnt_gno = (newsflash_rcnt_gno + newsflash_rcnt_gno_max) % newsflash_rcnt_gno_max;
#
# 		start = newsflash_rcnt_gno * gcnt;
# 		end = start + gcnt;
#
# 		for (i=0; i<total; i++)
# 		{
# 			li_name = 'newsflash_' + i;
# 			s_display = 'none';
# 			if (i>=start && i<end) s_display = '';
#
# 			if (document.getElementById(li_name)) {
# 				document.getElementById(li_name).style.display = s_display;
# 			}
# 		}
# 	}
#
# 	function view_newsflash_pause()
# 	{
# 		newsflash_rolling_tag = 0;
# 	}
#
# 	function view_newsflash_start()
# 	{
# 		newsflash_rolling_tag = 1;
# 	}
#
# 	function view_newsflash_rolling()
# 	{
# 		if(newsflash_rolling_tag == 1)
# 			view_newsflash('next');
# 	}
#
# 	function view_newsflash_move(mode) {
# 		if(newsflash_rolling_tag == 1) {
# 			view_newsflash(mode);
# 		}
# 		clearInterval(newsInterval);
# 		newsInterval = setInterval('view_newsflash_rolling()', 3000);
# 	}
#
# 	var newsInterval = setInterval('view_newsflash_rolling()', 3000);
# </script>
# <dl class="sub_tit_ticker">
# <dt>속보</dt>
# <dd>
# <span id="newsflash_0" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style=""><a href="/news/news_read.naver?article_id=0005282092&amp;office_id=009&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="“중개형 ISA도 나무에서” 나무증권, 중개형 ISA 이벤트 실시">“중개형 ISA도 나무에서” 나무증권. .</a></span>
# <span id="newsflash_1" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0002816266&amp;office_id=119&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="‘자본시장 메카’ 여의도 새 터전서 새 출발하는 증권사들">‘자본시장 메카’ 여의도 새 터전서. .</a></span>
# <span id="newsflash_2" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0000825343&amp;office_id=031&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="뜨거웠던 1분기 IPO, 상장 첫날 매도시 평균 168% 수익">뜨거웠던 1분기 IPO, 상장 첫날 매도. .</a></span>
# <span id="newsflash_3" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0005705301&amp;office_id=018&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="한국은행 “통안계정 7일물 3.50%, 28일물 3.52%에 각각 낙찰”">한국은행 “통안계정 7일물 3.50%, 2. .</a></span>
# <span id="newsflash_4" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0002289488&amp;office_id=016&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="LIG넥스원, 3000억 규모 토지·건물 취득 결정">LIG넥스원, 3000억 규모 토지·건물 . .</a></span>
# <span id="newsflash_5" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0012466564&amp;office_id=003&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="한투운용, 베트남그로스UH 펀드 1년 수익률 1위">한투운용, 베트남그로스UH 펀드 1년 . .</a></span>
# <span id="newsflash_6" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0012466556&amp;office_id=003&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="미래산업, 넵콘 상하이 참가…글로벌 시장 공략">미래산업, 넵콘 상하이 참가…글로벌. .</a></span>
# <span id="newsflash_7" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0012466545&amp;office_id=003&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title='한화에어로스페이스 "인적분할 검토하나 확정 안 돼"'>한화에어로스페이스 "인적분할 검토. .</a></span>
# <span id="newsflash_8" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0003194573&amp;office_id=030&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="우리은행 '사고 Zero 서포터즈' 2기 출범">우리은행 '사고 Zero 서포터즈' 2기 . .</a></span>
# <span id="newsflash_9" onmouseout="view_newsflash_start()" onmouseover="view_newsflash_pause()" style="display:none"><a href="/news/news_read.naver?article_id=0005400674&amp;office_id=277&amp;mode=LSS3D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=401" title="이수그룹-지용킴, 2024 SS 컬렉션 출시">이수그룹-지용킴, 2024 SS 컬렉션 출. .</a></span>
# <span class="btn">
# <a href="javascript:view_newsflash_move('prev');"><img alt="이전 뉴스보기" height="17" src="https://ssl.pstatic.net/static/nfinance/2015/news_ticker_arrow_prev.png" width="17"/></a>
# <a href="javascript:view_newsflash_move('next');"><img alt="다음 뉴스보기" height="17" src="https://ssl.pstatic.net/static/nfinance/2015/news_ticker_arrow_next.png" width="17"/></a>
# </span>
# </dd>
# </dl>
# <ul class="realtimeNewsList _replaceNewsLink">
# <li class="newsList top">
# <!-- 상단 10개의 기사 -->
# <dl>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0005282092&amp;office_id=009&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/009/2024/04/02/5282092.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0005282092&amp;office_id=009&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="“중개형 ISA도 나무에서” 나무증권, 중개형 ISA 이벤트 실시">“중개형 ISA도 나무에서” 나무증권, 중개형 ISA 이벤트 실시</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										NH투자증권 나무증권은 ‘중개형 ISA(Individual Savings Account·개인종합자산관리계좌)도 나무에서 시작!’ 이벤트를 진행한...
#
#
#
# 								<span class="press">매일경제</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:15</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0002816266&amp;office_id=119&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/119/2024/04/02/2816266.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0002816266&amp;office_id=119&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="‘자본시장 메카’ 여의도 새 터전서 새 출발하는 증권사들">‘자본시장 메카’ 여의도 새 터전서 새 출발하는 증권사들</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										최근 증권사들이 자본시장의 메카(중심지)인 여의도에서 입지를 선점하기 위해 입성 혹은 이주를 택하고 있다. 2일 금융투자업계에 따르면 국내 증권...
#
#
#
# 								<span class="press">데일리안</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:15</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0000825343&amp;office_id=031&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/031/2024/04/02/825343.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0000825343&amp;office_id=031&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="뜨거웠던 1분기 IPO, 상장 첫날 매도시 평균 168% 수익">뜨거웠던 1분기 IPO, 상장 첫날 매도시 평균 168% 수익</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										엔젤로보틱스를 끝으로 올해 1분기 기업공개(IPO) 시장이 마무리됐다. 1분기 상장 기업 27곳 중 코넥스·재상장·이전상장·스팩 등을 제외한 1...
#
#
#
# 								<span class="press">아이뉴스24</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:13</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0005705301&amp;office_id=018&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/018/2024/04/02/5705301.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0005705301&amp;office_id=018&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="한국은행 “통안계정 7일물 3.50%, 28일물 3.52%에 각각 낙찰”">한국은행 “통안계정 7일물 3.50%, 28일물 3.52%에 각각 낙찰”</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										한국은행은 2일 통화안정계정예치금 경쟁입찰 실시 결과 7일물이 3.50%에 4조6800억원 낙찰, 28일물이 3.52%에 2조원 낙찰됐다고 밝혔...
#
#
#
# 								<span class="press">이데일리</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:11</span>
# </dd>
# <dt class="articleSubject">
# <a href="/news/news_read.naver?article_id=0002289488&amp;office_id=016&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="LIG넥스원, 3000억 규모 토지·건물 취득 결정">LIG넥스원, 3000억 규모 토지·건물 취득 결정</a>
# </dt>
# <dd class="articleSummary">
#
#
#
# 										LIG넥스원은 미래기술을 위한 R&amp;D 인프라 확보 목적으로 재단법인 세종연구소로부터 성남시 소재 토지 및 건물을 취득하기로 결정했다고 2일 공시했다. 취득금액은 3000억...
#
#
# 								<span class="press">헤럴드경제</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:11</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0012466564&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/003/2024/04/02/12466564.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0012466564&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="한투운용, 베트남그로스UH 펀드 1년 수익률 1위">한투운용, 베트남그로스UH 펀드 1년 수익률 1위</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										한국투자신탁운용은 한국투자베트남그로스UH(C-W)가 운용설정액 500억원 이상의 베트남 펀드 가운데 1년 수익률 1위를 차지했다고 2일 밝혔다....
#
#
#
# 								<span class="press">뉴시스</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:09</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0012466556&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/003/2024/04/02/12466556.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0012466556&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="미래산업, 넵콘 상하이 참가…글로벌 시장 공략">미래산업, 넵콘 상하이 참가…글로벌 시장 공략</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										반도체 후공정 검사장비 제조 전문기업 미래산업은 이달 말 중국 상하이에서 개최되는 전자부품 박람회 '넵콘 상하이(Nepcon Shanhai) 2...
#
#
#
# 								<span class="press">뉴시스</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:07</span>
# </dd>
# <dt class="articleSubject">
# <a href="/news/news_read.naver?article_id=0012466545&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="한화에어로스페이스 " 검토하나="" 돼""="" 안="" 인적분할="" 확정="">한화에어로스페이스 "인적분할 검토하나 확정 안 돼"</a>
# </dt>
# <dd class="articleSummary">
#
#
#
# 										한화에어로스페이스는 인적분할을 추진한다는 언론 보도에 대해 "주주가치와 경영효율성 제고를 위해 당사가 영위하는 사업특성을 고려한 인적분할을 검토하고 있으나 아직 확정된 사...
#
#
# 								<span class="press">뉴시스</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:07</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0003194573&amp;office_id=030&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/030/2024/04/02/3194573.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0003194573&amp;office_id=030&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="우리은행 '사고 Zero 서포터즈' 2기 출범">우리은행 '사고 Zero 서포터즈' 2기 출범</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										우리은행(행장 조병규)은 지난 1일 '사고 Zero 서포터즈' 2기 발대식을 열고, '2024년 금융사고 Zero 은행'을 위한 활동을 시작했다...
#
#
#
# 								<span class="press">전자신문</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:05</span>
# </dd>
# <dt class="articleSubject">
# <a href="/news/news_read.naver?article_id=0005400674&amp;office_id=277&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="이수그룹-지용킴, 2024 SS 컬렉션 출시">이수그룹-지용킴, 2024 SS 컬렉션 출시</a>
# </dt>
# <dd class="articleSummary">
#
#
#
# 										이수그룹이 지용킴 디자이너와 2024 SS 컬렉션을 한정판으로 출시한다고 2일 밝혔다. 이수그룹은 지난해부터 지용킴과 폐근무복으로 가방과 의류를 제작하는 업사이클링 프로젝...
#
#
# 								<span class="press">아시아경제</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:04</span>
# </dd>
# </dl>
# <!-- 상단 10개의 기사 끝 -->
# </li>
# <li class="newsList">
# <!-- 하단 10개의 기사 -->
# <dl>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0001155757&amp;office_id=215&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/215/2024/04/02/1155757.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0001155757&amp;office_id=215&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title='"FDA 승인 획득"…코어라인소프트, 미국 간다 [엔터프라이스]'>"FDA 승인 획득"…코어라인소프트, 미국 간다 [엔터프라이스]</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										다음 소식은 정 기자가 준비했죠. 어떤 기업 소식입니까? 오늘 따끈따끈한 자료를 낸 AI 의료기업 '코어라인소프트' 소식으로 준비했습니다. 코어...
#
#
#
# 								<span class="press">한국경제TV</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:03</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0001155756&amp;office_id=215&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/215/2024/04/02/1155756.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0001155756&amp;office_id=215&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="'사면초가' 철강업계…포스코 '인내의 시간' [엔터프라이스]">'사면초가' 철강업계…포스코 '인내의 시간' [엔터프라이스]</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										왼쪽에서 레프트 훅이 날아오고, 오른쪽에선 라이트 스트레이트가 꽂힙니다. 우리나라 철강 업계가 처한 상황인데요. 태평양 건너 미국에선 높은 세금...
#
#
#
# 								<span class="press">한국경제TV</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:03</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0005282083&amp;office_id=009&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/009/2024/04/02/5282083.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0005282083&amp;office_id=009&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="한투證, 글로벌 대체투자 운용사 TPG 안젤로고든과 부동산투자 MOU">한투證, 글로벌 대체투자 운용사 TPG 안젤로고든과 부동산투자 MOU</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										한국투자증권은 글로벌 사모펀드 운용사인 텍사스퍼시픽그룹(TPG)의 대체투자 전문 운용사 TPG 안젤로고든과 부동산 스페셜시츄에이션(특수상황) 투...
#
#
#
# 								<span class="press">매일경제</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:02</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0003194568&amp;office_id=030&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/030/2024/04/02/3194568.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0003194568&amp;office_id=030&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="KB국민은행, LG유플러스 손잡고 환전수수료 낮춘다">KB국민은행, LG유플러스 손잡고 환전수수료 낮춘다</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										KB국민은행(행장 이재근)이 LG유플러스(대표 황현식)와 마케팅 업무제휴를 체결하고 LG유플러스 해외로밍고객을 대상으로 환율 우대 혜택을 제공한...
#
#
#
# 								<span class="press">전자신문</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:02</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0000793867&amp;office_id=469&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/469/2024/04/02/793867.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0000793867&amp;office_id=469&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="지배구조 우수 기업에 감사인지정 면제... '밸류업' 인센티브">지배구조 우수 기업에 감사인지정 면제... '밸류업' 인센티브</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										금융당국이 '밸류업 프로그램'의 일환으로 추가 인센티브를 내놨다. 지배구조 개선에 힘쓰는 기업에는 '주기적 감사인 지정 제도'를 면제해주는 방안...
#
#
#
# 								<span class="press">한국일보</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:01</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0001155754&amp;office_id=215&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/215/2024/04/02/1155754.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0001155754&amp;office_id=215&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="&quot;한화에어로스페이스, 인적분할 추진 검토&quot;…주가 '쑥'">"한화에어로스페이스, 인적분할 추진 검토"…주가 '쑥'</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										한화에어로스페이스가 인적분할을 추진을 검토하고 있다는 소식에 주가가 급등 중이다. 2일 유가증권시장에서 오후 2시 52분 기준 한화에어로스페이스...
#
#
#
# 								<span class="press">한국경제TV</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 15:00</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0000982690&amp;office_id=366&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/366/2024/04/02/982690.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0000982690&amp;office_id=366&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="[특징주] ‘인적분할 추진’ 한화에어로, 사상 최고가">[특징주] ‘인적분할 추진’ 한화에어로, 사상 최고가</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										한화에어로스페이스가 인적분할을 추진한다는 사실이 알려지면서 주가가 역대 최고가를 찍었다. 한화에어로스페이스 주식은 2일 오후 2시 50분 유가증...
#
#
#
# 								<span class="press">조선비즈</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 14:59</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0012466487&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/003/2024/04/02/12466487.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0012466487&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="진영, 에어돔 스마트팜 공동사업 진행 MOU">진영, 에어돔 스마트팜 공동사업 진행 MOU</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										진영이 반도체, 2차전지에 이어 스마트팜용 필름으로 산업용 필름 포트폴리오를 다각화한다. 진영은 D&amp;W그룹, 청토씨앤디와 에어돔 스마트팜 공동사...
#
#
#
# 								<span class="press">뉴시스</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 14:57</span>
# </dd>
# <dt class="articleSubject">
# <a href="/news/news_read.naver?article_id=0012466486&amp;office_id=003&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="다원시스, 3일 기업설명회 개최">다원시스, 3일 기업설명회 개최</a>
# </dt>
# <dd class="articleSummary">
#
#
#
# 										다원시스는 3일 오전 9시10분 서울 여의도 등 기관투자자 회의실에서 국내 기관투자자를 대상으로 회사 사업현황에 대한 이해도와 기업가치 제고를 위해 기업설명회(IR)를 개...
#
#
# 								<span class="press">뉴시스</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 14:56</span>
# </dd>
# <dt class="thumb">
# <a href="/news/news_read.naver?article_id=0005282077&amp;office_id=009&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1"><img alt="" onerror="this.src='https://ssl.pstatic.net/static/nfinance/2017/02/27/thumb_72x54.gif'" src="https://imgnews.pstatic.net/image/thumb70/009/2024/04/02/5282077.jpg"/></a>
# </dt>
# <dd class="articleSubject">
# <a href="/news/news_read.naver?article_id=0005282077&amp;office_id=009&amp;mode=LSS2D&amp;type=0§ion_id=101§ion_id2=258§ion_id3=&amp;date=20240402&amp;page=1" title="동학개미 “모처럼 달리는 코스피, 더 간다?”…빚투 규모 20조 육박">동학개미 “모처럼 달리는 코스피, 더 간다?”…빚투 규모 20조 육박</a>
# </dd>
# <dd class="articleSummary">
#
#
# 										코스피 지수가 무난히 2700선에 안착하면서 3000선까지 도달할 수 있다는 증권가의 긍정적인 전망이 나오자 개인 투자자들의 투자열기도 모처럼 ...
#
#
#
# 								<span class="press">매일경제</span>
# <span class="bar">|</span>
# <span class="wdate">2024-04-02 14:56</span>
# </dd>
# </dl>
# <!-- 하단 10개의 기사 끝 -->
# </li>
# </ul>
# <!-- paging -->
# <table align="center" class="Nnavi" summary="페이지 네비게이션 리스트">
# <caption>페이지 네비게이션</caption>
# <tr>
# <td>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr align="center">
# <td class="on">
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=1">1</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=2">2</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=3">3</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=4">4</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=5">5</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=6">6</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=7">7</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=8">8</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=9">9</a>
# </td>
# <td>
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=10">10</a>
# </td>
# <td class="pgR">
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=11">
# 				다음<img alt="" border="0" height="5" src="https://ssl.pstatic.net/static/n/cmn/bu_pgarR.gif" width="3"/>
# </a>
# </td>
# <td class="pgRR">
# <a href="/news/news_list.naver?mode=LSS2D&amp;page=37">맨뒤
# 				<img alt="" border="0" height="5" src="https://ssl.pstatic.net/static/n/cmn/bu_pgarRR.gif" width="8"/>
# </a>
# </td>
# </tr>
# </table>
# </td>
# </tr>
# </table>
# <!-- //paging -->
# <div class="pagenavi_day">
# <span class="viewday">04월02일(화)</span>
# <span class="devidebar">·</span>
# <a href="/news/news_list.naver?mode=LSS2D§ion_id=101§ion_id2=258&amp;date=20240401">04월01일(월)</a>
# <span class="devidebar">·</span>
# <a href="/news/news_list.naver?mode=LSS2D§ion_id=101§ion_id2=258&amp;date=20240331">03월31일(일)</a>
# <span class="devidebar">·</span>
# <a href="/news/news_list.naver?mode=LSS2D§ion_id=101§ion_id2=258&amp;date=20240330">03월30일(토)</a>
# <span class="devidebar">·</span>
# <a href="/news/news_list.naver?mode=LSS2D§ion_id=101§ion_id2=258&amp;date=20240329">03월29일(금)</a>
# </div>
# <!--// 날짜별 페이징 -->
# <!-- //페이징 영역 -->
# </div>
# <!-- //컨텐츠 -->
# <!--  right area -->
# <div id="contentarea_right2">
# <!-- 우측메뉴 끼워넣기 -->
# <!--  여러개가 뉴스홈 배너로 등록되었을 경우에는 하나의 경우만 뿌려주게 한다. -->
# <!-- 가장 많이 본 뉴스 -->
# <div class="box_type_r"><div class="box_type_r_top">
# <h2 class="r_subtlt tlt_bottom_line"><img alt="가장 많이 본 뉴스" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/rtlt_best_news.gif" width="86"/><span class="tlt_more"><a href="/news/news_list.naver?mode=RANK" onclick="clickcr(this, 'rnw.more', '', '', event)">더보기</a></span></h2>
# <ul class="right_list_1_2">
# <li><a href="/news/news_read.naver?article_id=0004967544&amp;office_id=015&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0004967544', '1', event)" title="&quot;23만원까지 나왔다&quot; 환호…신고가 행진에 '20만닉스' 성큼">"23만원까지 나왔다" 환호…신고가 행진에 '20만닉스' 성큼</a></li>
# <li><a href="/news/news_read.naver?article_id=0007452669&amp;office_id=421&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0007452669', '2', event)" title="[단독] 한화에어로스페이스 인적분할 추진…김동관, 승계구도 굳힌다">[단독] 한화에어로스페이스 인적분할 추진…김동관, 승계구도 굳힌다</a></li>
# <li><a href="/news/news_read.naver?article_id=0005020306&amp;office_id=008&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0005020306', '3', event)" title='"엄마가 준 용돈으로 주식" 조기 교육…흙수저는 "그게 뭐죠?"'>"엄마가 준 용돈으로 주식" 조기 교육…흙수저는 "그게 뭐죠?"</a></li>
# <li><a href="/news/news_read.naver?article_id=0001155662&amp;office_id=215&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0001155662', '4', event)" title='"삼성전자, 엔비디아 HBM 납품 논란 불필요"'>"삼성전자, 엔비디아 HBM 납품 논란 불필요"</a></li>
# <li class="division"></li>
# <li><a href="/news/news_read.naver?article_id=0005282038&amp;office_id=009&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0005282038', '5', event)" title="멀어지는 6월 금리인하...떨어지는 비트코인[매일코인]">멀어지는 6월 금리인하...떨어지는 비트코인[매일코인]</a></li>
# <li><a href="/news/news_read.naver?article_id=0007452990&amp;office_id=421&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0007452990', '6', event)" title="삼성전자 장중 '8만 5000원' 찍었다…하루 만에 시총 18조 '쑥'[핫종목]">삼성전자 장중 '8만 5000원' 찍었다…하루 만에 시총 18조 '쑥'[핫종목]</a></li>
# <li><a href="/news/news_read.naver?article_id=0004967674&amp;office_id=015&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0004967674', '7', event)" title="롤러코스터 탄 비트코인…반감기 앞두고 매수·매도 '줄다리기'">롤러코스터 탄 비트코인…반감기 앞두고 매수·매도 '줄다리기'</a></li>
# <li><a href="/news/news_read.naver?article_id=0005020276&amp;office_id=008&amp;mode=RANK&amp;typ=0" onclick="clickcr(this, 'rnw.list', '0005020276', '8', event)" title="코인 '영끌' 20대, 고금리 리볼빙 '덜컥' 받더니…4년 새 연체율 급등">코인 '영끌' 20대, 고금리 리볼빙 '덜컥' 받더니…4년 새 연체율 급등</a></li>
# </ul>
# </div></div>
# <!-- //가장 많이 본 뉴스 -->
# <!--  여러개가 뉴스홈 배너로 등록되었을 경우에는 하나의 경우만 뿌려주게 한다. -->
# <!-- 인기검색어 -->
# <div class="box_type_r"><div class="box_type_r_top">
# <h2 class="r_subtlt tlt_bottom_line"><img alt="인기검색어" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/rtlt_best_keyword.gif" width="51"/><span class="tlt_more"><a href="/sise/lastsearch2.naver">더보기</a></span></h2>
# <table cellpadding="0" cellspacing="0" class="type_r1" summary="인기검색어 리스트">
# <caption>인기검색어</caption>
# <col width="11%"/><col width="*"/><col width="30%"/><col width="13%"/>
# <tr>
# <td align="right" class="tr"><img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/ico_n01.gif" width="11"/></td>
# <td><a class="company" href="/item/main.naver?code=005930">삼성전자</a></td>
# <td class="number">85,000</td>
# <td class="tc"><img alt="상승" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/></td>
# </tr>
# <tr>
# <td align="right" class="tr"><img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/ico_n02.gif" width="11"/></td>
# <td><a class="company" href="/item/main.naver?code=012450">한화에어로스페이스</a></td>
# <td class="number">238,000</td>
# <td class="tc"><img alt="상승" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/></td>
# </tr>
# <tr>
# <td align="right" class="tr"><img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/ico_n03.gif" width="11"/></td>
# <td><a class="company" href="/item/main.naver?code=024060">흥구석유</a></td>
# <td class="number">13,050</td>
# <td class="tc"><img alt="상한" class="updown" height="11" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up02.gif" width="7"/></td>
# </tr>
# <tr>
# <td align="right" class="tr"><img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/ico_n04.gif" width="11"/></td>
# <td><a class="company" href="/item/main.naver?code=042700">한미반도체</a></td>
# <td class="number">145,300</td>
# <td class="tc"><img alt="상승" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_up.gif" width="7"/></td>
# </tr>
# <tr>
# <td align="right" class="tr"><img alt="01" height="11" src="https://ssl.pstatic.net/imgstock/images5/news/ico_n05.gif" width="11"/></td>
# <td><a class="company" href="/item/main.naver?code=000250">삼천당제약</a></td>
# <td class="number">118,400</td>
# <td class="tc"><img alt="하락" class="updown" height="6" src="https://ssl.pstatic.net/imgstock/images/images4/ico_down.gif" width="7"/></td>
# </tr>
# </table>
# </div></div>
# <!-- //인기검색어 -->
# <!-- //우측메뉴 끼워넣기 -->
# </div>
# <!-- // right area -->
# <div class="c"></div>
# </div>
# </div>
# <div class="footer_news" id="footer">
# <ul>
# <li class="first">
# <a href="https://policy.naver.com/rules/service.html" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">이용약관</a>
# </li>
# <li>기사배열 원칙 책임자 : 유봉석</li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li>
# <a href="https://policy.naver.com/rules/privacy.html" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a>
# </li>
# <li>
# <a href="https://help.naver.com/service/5603/category/bookmark" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">고객센터</a>
# </li>
# </ul>
# <p class="desc">
# 			뉴스 서비스는 네이버㈜에서 운영하며, 본 콘텐츠의 저작권은 제공처 또는 네이버㈜에 있습니다. 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.<span class="naver">© NAVER Corp.</span>
# </p>
# <ul>
# <li class="first">
# <a href="https://new-m.pay.naver.com/member/terms-policy/naver-financial-service" onclick="clickcr(this, 'fot.service', '', '', event);" target="_blank">이용약관</a>
# </li>
# <li>
# <a href="https://new-m.pay.naver.com/member/terms-policy/privacy" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank"><strong>개인정보처리방침</strong></a>
# </li>
# <li>
# <a href="/rules.naver" onclick="clickcr(this, 'fot.policy', '', '', event);" target="_blank">게시판 운영원칙</a>
# </li>
# <li>
# <a href="https://help.naver.com/alias/contents2/finance/finance_1.naver" onclick="clickcr(this, 'fot.help', '', '', event);" target="_blank">증권 고객센터</a>
# </li>
# </ul>
# <p class="desc">
# 			네이버파이낸셜(주)이 제공하는 금융 정보는 <a class="desc_help" href="javascript:;" onclick="togglePanelFooter('footerPanel0');">콘텐츠 제공업체</a>로부터 받는 투자 참고사항이며, 오류가 발생하거나 지연될 수 있습니다.<br/>
# 			네이버파이낸셜(주)과 콘텐츠 제공업체는 제공된 정보에 의한 투자 결과에 법적인 책임을 지지 않습니다. 게시된 정보는 무단으로 배포할 수 없습니다.
# 		</p>
# <address>
# <a class="logo" href="https://www.naverfincorp.com/" onclick="clickcr(this, 'fot.nhn', '', '', event);" target="_blank"><img alt="NAVER FINANCIAL" height="12" src="https://ssl.pstatic.net/static/nfinance/img/logo_financial.png" width="160"/></a>
# </address>
# <div class="provider_layer" id="footerPanel0" onblur="hidePannel('footerPanel0')" style="display:none" tabindex="0">
# <strong class="provider_layer__tit">네이버파이낸셜에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>에프앤가이드</strong> 기업 및 재무정보<br/>
# <strong>KG제로인</strong> 해외 시세, 시장지표 정보<br/>
# <strong>한국예탁결제원</strong> 주주총회일, 전자투표 정보<br/>
# <strong>인포스탁</strong> 국내 테마 정보
# 			</div>
# <div class="provider_layer__info">
# <strong class="provider_layer__tit">네이버에 콘텐츠 제공</strong>
# <div class="provider_layer__txt">
# <strong>코스콤</strong> 국내 시세 정보
# 				</div>
# </div>
# <button class="button_close" onclick="hidePannel('footerPanel0')" type="button">
# <img alt="닫기" height="20" src="https://ssl.pstatic.net/static/nfinance/2022/footer_close.png" width="20"/>
# </button>
# </div>
# </div>
# <script type="text/javascript">
# function isVisible(obj) {
#     if (obj == document) return true
#
#     if (!obj) return false
#     if (!obj.parentNode) return false
#     if (obj.style) {
#         if (obj.style.display == 'none') return false
#         if (obj.style.visibility == 'hidden') return false
#     }
#
#     if (window.getComputedStyle) {
#         var style = window.getComputedStyle(obj, "")
#         if (style.display == 'none') return false
#         if (style.visibility == 'hidden') return false
#     }
#
#     var style = obj.currentStyle
#     if (style) {
#         if (style['display'] == 'none') return false
#         if (style['visibility'] == 'hidden') return false
#     }
#
#     return isVisible(obj.parentNode)
# }
#
# function isChildOf(myobj, containerObj) {
# 	while(myobj != undefined) {
# 		if (myobj == document.body) {
# 			break;
# 		}
# 		if (myobj == containerObj) {
# 			return true;
# 		}
# 		myobj = myobj.parentElement;
# 	}
# 	return false;
# }
#
# function gnbLayerClose(e){
# 	var target = e.target ? e.target : e.srcElement;
# 	if (isVisible(document.getElementById('gnb_service_lyr')) || isVisible(document.getElementById('gnb_notice_lyr')) ||isVisible(document.getElementById('gnb_my_lyr')) ) {
# 		if (!isChildOf(target, document.getElementById('gnb'))) {
# 			gnbAllLayerClose();
# 		}
# 	}
# }
#
# var isIE = (navigator.userAgent.toLowerCase().indexOf("msie")!=-1 && window.document.all) ? true:false;
# if (isIE) {
# 	document.attachEvent('onmousedown', gnbLayerClose);
# } else {
# 	window.addEventListener('mousedown', gnbLayerClose);
# }
#
# function showPannel(layerId){
#     var layer = jindo.$(layerId);
#     layer.style.display='block';
#
#     if (layerId == "summary_lyr") {
#         var layerHeight = jindo.$Element(layer).height();
#         jindo.$Element("summary_ifr").height(layerHeight);
#     }
# }
#
# function hidePannel(layerId){
#     var layer = jindo.$(layerId);
#     layer.style.display='none';
# }
#
# function togglePanelFooter(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# // add data-useragent
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#
# // _replaceNewsLink class 하위의 a 태그 조회 후 redirect
# jindo.$Fn(function () {
# 	jindo.$$("._replaceNewsLink a").forEach(function(ele){
# 		var urls = ele.href.split("?");
# 		if (urls[0].indexOf("/news_read.naver") > 0 || urls[0].indexOf("/newsRead.naver") > 0) {
# 			var param = jindo.$S(urls[1]).parseString();
# 			var oid = param.office_id ? param.office_id : param.officeId;
# 			var aid = param.article_id ? param.article_id : param.articleId;
#
# 			ele.target = "_blank";
# 			ele.href = jindo.$S("https://n.news.naver.com/mnews/article/%s/%s").format(oid, aid);
# 		}
# 	});
# }).attach(document, "domready");
# </script>
# </div>
# </body>
# </html>

# %%
# 실시간뉴스속보 목록
news_list = html.select_one('#contentarea_left > ul')
type(news_list)
# Out:
# bs4.element.Tag

# %%
articleSubject_list = news_list.select('.articleSubject')
articleSummary_list = news_list.select('.articleSummary')
len(articleSubject_list), len(articleSummary_list)
# Out:
# (20, 20)

# %%
# 뉴스 제목 목록 가져오기
news_subjects = [ subject.text for subject in articleSubject_list ]
# 뉴스 링크 목록 가져오기
news_home_url = 'https://finance.naver.com'
news_link = [ f"{news_home_url}{subject.select_one('a')['href']}" for subject in articleSubject_list ]
# 뉴스 요약 목록 가져오기
news_summaries = [ summary.get_text() for summary in articleSummary_list ]
# 뉴스 언론사 목록 가져오기
media_companies = [ summary.select_one('.press').text for summary in articleSummary_list ]
# 뉴스 작성일
news_cdates = [ summary.select_one('.wdate').text for summary in articleSummary_list ]

# %% [markdown]
# * bs4.element.Tag.text  :  엘리먼트 컨텐츠의 모든 텍스트 가져오기
# * bs4.element.Tag.get_text() : 엘리먼트 컨텐츠의 첫번째노드의 텍스트 가져오기
# * bs4.element.Tag.contents : 엘리먼트 컨텐즈를 html로 가져오기

# %%
# zip()함수를 사용해서 여러 리스트의 요소를 묶기
zipped_lists = zip(news_subjects,news_link,news_summaries,media_companies,news_cdates)
# zip객체를 리스트로 변환
result_list = list(zipped_lists)

# %%
result_list[0:3]
# Out:
# [('\n“중개형 ISA도 나무에서” 나무증권, 중개형 ISA 이벤트 실시\n',
#   'https://finance.naver.com/news/news_read.naver?article_id=0005282092&office_id=009&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\tNH투자증권 나무증권은 ‘중개형 ISA(Individual Savings Account·개인종합자산관리계좌)도 나무에서 시작!’ 이벤트를 진행한...\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t매일경제\n|\n2024-04-02 15:15\n',
#   '매일경제',
#   '2024-04-02 15:15'),
#  ('\n‘자본시장 메카’ 여의도 새 터전서 새 출발하는 증권사들\n',
#   'https://finance.naver.com/news/news_read.naver?article_id=0002816266&office_id=119&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t최근 증권사들이 자본시장의 메카(중심지)인 여의도에서 입지를 선점하기 위해 입성 혹은 이주를 택하고 있다. 2일 금융투자업계에 따르면 국내 증권...\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t데일리안\n|\n2024-04-02 15:15\n',
#   '데일리안',
#   '2024-04-02 15:15'),
#  ('\n뜨거웠던 1분기 IPO, 상장 첫날 매도시 평균 168% 수익\n',
#   'https://finance.naver.com/news/news_read.naver?article_id=0000825343&office_id=031&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t엔젤로보틱스를 끝으로 올해 1분기 기업공개(IPO) 시장이 마무리됐다. 1분기 상장 기업 27곳 중 코넥스·재상장·이전상장·스팩 등을 제외한 1...\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t아이뉴스24\n|\n2024-04-02 15:13\n',
#   '아이뉴스24',
#   '2024-04-02 15:13')]

# %%
[ num for num in range(5)]
list( num for num in range(5) )
tuple( num for num in range(5) )
# Out:
# (0, 1, 2, 3, 4)

# %%
# \n \t 제거하기
[ tuple(ele.replace('\n','').replace('\t','').strip() for ele in t) for t in result_list ]
# Out:
# [('“중개형 ISA도 나무에서” 나무증권, 중개형 ISA 이벤트 실시',
#   'https://finance.naver.com/news/news_read.naver?article_id=0005282092&office_id=009&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   'NH투자증권 나무증권은 ‘중개형 ISA(Individual Savings Account·개인종합자산관리계좌)도 나무에서 시작!’ 이벤트를 진행한...매일경제|2024-04-02 15:15',
#   '매일경제',
#   '2024-04-02 15:15'),
#  ('‘자본시장 메카’ 여의도 새 터전서 새 출발하는 증권사들',
#   'https://finance.naver.com/news/news_read.naver?article_id=0002816266&office_id=119&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '최근 증권사들이 자본시장의 메카(중심지)인 여의도에서 입지를 선점하기 위해 입성 혹은 이주를 택하고 있다. 2일 금융투자업계에 따르면 국내 증권...데일리안|2024-04-02 15:15',
#   '데일리안',
#   '2024-04-02 15:15'),
#  ('뜨거웠던 1분기 IPO, 상장 첫날 매도시 평균 168% 수익',
#   'https://finance.naver.com/news/news_read.naver?article_id=0000825343&office_id=031&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '엔젤로보틱스를 끝으로 올해 1분기 기업공개(IPO) 시장이 마무리됐다. 1분기 상장 기업 27곳 중 코넥스·재상장·이전상장·스팩 등을 제외한 1...아이뉴스24|2024-04-02 15:13',
#   '아이뉴스24',
#   '2024-04-02 15:13'),
#  ('한국은행 “통안계정 7일물 3.50%, 28일물 3.52%에 각각 낙찰”',
#   'https://finance.naver.com/news/news_read.naver?article_id=0005705301&office_id=018&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '한국은행은 2일 통화안정계정예치금 경쟁입찰 실시 결과 7일물이 3.50%에 4조6800억원 낙찰, 28일물이 3.52%에 2조원 낙찰됐다고 밝혔...이데일리|2024-04-02 15:11',
#   '이데일리',
#   '2024-04-02 15:11'),
#  ('LIG넥스원, 3000억 규모 토지·건물 취득 결정',
#   'https://finance.naver.com/news/news_read.naver?article_id=0002289488&office_id=016&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   'LIG넥스원은 미래기술을 위한 R&D 인프라 확보 목적으로 재단법인 세종연구소로부터 성남시 소재 토지 및 건물을 취득하기로 결정했다고 2일 공시했다. 취득금액은 3000억...헤럴드경제|2024-04-02 15:11',
#   '헤럴드경제',
#   '2024-04-02 15:11'),
#  ('한투운용, 베트남그로스UH 펀드 1년 수익률 1위',
#   'https://finance.naver.com/news/news_read.naver?article_id=0012466564&office_id=003&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '한국투자신탁운용은 한국투자베트남그로스UH(C-W)가 운용설정액 500억원 이상의 베트남 펀드 가운데 1년 수익률 1위를 차지했다고 2일 밝혔다....뉴시스|2024-04-02 15:09',
#   '뉴시스',
#   '2024-04-02 15:09'),
#  ('미래산업, 넵콘 상하이 참가…글로벌 시장 공략',
#   'https://finance.naver.com/news/news_read.naver?article_id=0012466556&office_id=003&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   "반도체 후공정 검사장비 제조 전문기업 미래산업은 이달 말 중국 상하이에서 개최되는 전자부품 박람회 '넵콘 상하이(Nepcon Shanhai) 2...뉴시스|2024-04-02 15:07",
#   '뉴시스',
#   '2024-04-02 15:07'),
#  ('한화에어로스페이스 "인적분할 검토하나 확정 안 돼"',
#   'https://finance.naver.com/news/news_read.naver?article_id=0012466545&office_id=003&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '한화에어로스페이스는 인적분할을 추진한다는 언론 보도에 대해 "주주가치와 경영효율성 제고를 위해 당사가 영위하는 사업특성을 고려한 인적분할을 검토하고 있으나 아직 확정된 사...뉴시스|2024-04-02 15:07',
#   '뉴시스',
#   '2024-04-02 15:07'),
#  ("우리은행 '사고 Zero 서포터즈' 2기 출범",
#   'https://finance.naver.com/news/news_read.naver?article_id=0003194573&office_id=030&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   "우리은행(행장 조병규)은 지난 1일 '사고 Zero 서포터즈' 2기 발대식을 열고, '2024년 금융사고 Zero 은행'을 위한 활동을 시작했다...전자신문|2024-04-02 15:05",
#   '전자신문',
#   '2024-04-02 15:05'),
#  ('이수그룹-지용킴, 2024 SS 컬렉션 출시',
#   'https://finance.naver.com/news/news_read.naver?article_id=0005400674&office_id=277&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '이수그룹이 지용킴 디자이너와 2024 SS 컬렉션을 한정판으로 출시한다고 2일 밝혔다. 이수그룹은 지난해부터 지용킴과 폐근무복으로 가방과 의류를 제작하는 업사이클링 프로젝...아시아경제|2024-04-02 15:04',
#   '아시아경제',
#   '2024-04-02 15:04'),
#  ('"FDA 승인 획득"…코어라인소프트, 미국 간다 [엔터프라이스]',
#   'https://finance.naver.com/news/news_read.naver?article_id=0001155757&office_id=215&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   "다음 소식은 정 기자가 준비했죠. 어떤 기업 소식입니까? 오늘 따끈따끈한 자료를 낸 AI 의료기업 '코어라인소프트' 소식으로 준비했습니다. 코어...한국경제TV|2024-04-02 15:03",
#   '한국경제TV',
#   '2024-04-02 15:03'),
#  ("'사면초가' 철강업계…포스코 '인내의 시간' [엔터프라이스]",
#   'https://finance.naver.com/news/news_read.naver?article_id=0001155756&office_id=215&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '왼쪽에서 레프트 훅이 날아오고, 오른쪽에선 라이트 스트레이트가 꽂힙니다. 우리나라 철강 업계가 처한 상황인데요. 태평양 건너 미국에선 높은 세금...한국경제TV|2024-04-02 15:03',
#   '한국경제TV',
#   '2024-04-02 15:03'),
#  ('한투證, 글로벌 대체투자 운용사 TPG 안젤로고든과 부동산투자 MOU',
#   'https://finance.naver.com/news/news_read.naver?article_id=0005282083&office_id=009&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '한국투자증권은 글로벌 사모펀드 운용사인 텍사스퍼시픽그룹(TPG)의 대체투자 전문 운용사 TPG 안젤로고든과 부동산 스페셜시츄에이션(특수상황) 투...매일경제|2024-04-02 15:02',
#   '매일경제',
#   '2024-04-02 15:02'),
#  ('KB국민은행, LG유플러스 손잡고 환전수수료 낮춘다',
#   'https://finance.naver.com/news/news_read.naver?article_id=0003194568&office_id=030&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   'KB국민은행(행장 이재근)이 LG유플러스(대표 황현식)와 마케팅 업무제휴를 체결하고 LG유플러스 해외로밍고객을 대상으로 환율 우대 혜택을 제공한...전자신문|2024-04-02 15:02',
#   '전자신문',
#   '2024-04-02 15:02'),
#  ("지배구조 우수 기업에 감사인지정 면제... '밸류업' 인센티브",
#   'https://finance.naver.com/news/news_read.naver?article_id=0000793867&office_id=469&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   "금융당국이 '밸류업 프로그램'의 일환으로 추가 인센티브를 내놨다. 지배구조 개선에 힘쓰는 기업에는 '주기적 감사인 지정 제도'를 면제해주는 방안...한국일보|2024-04-02 15:01",
#   '한국일보',
#   '2024-04-02 15:01'),
#  ('"한화에어로스페이스, 인적분할 추진 검토"…주가 \'쑥\'',
#   'https://finance.naver.com/news/news_read.naver?article_id=0001155754&office_id=215&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '한화에어로스페이스가 인적분할을 추진을 검토하고 있다는 소식에 주가가 급등 중이다. 2일 유가증권시장에서 오후 2시 52분 기준 한화에어로스페이스...한국경제TV|2024-04-02 15:00',
#   '한국경제TV',
#   '2024-04-02 15:00'),
#  ('[특징주] ‘인적분할 추진’ 한화에어로, 사상 최고가',
#   'https://finance.naver.com/news/news_read.naver?article_id=0000982690&office_id=366&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '한화에어로스페이스가 인적분할을 추진한다는 사실이 알려지면서 주가가 역대 최고가를 찍었다. 한화에어로스페이스 주식은 2일 오후 2시 50분 유가증...조선비즈|2024-04-02 14:59',
#   '조선비즈',
#   '2024-04-02 14:59'),
#  ('진영, 에어돔 스마트팜 공동사업 진행 MOU',
#   'https://finance.naver.com/news/news_read.naver?article_id=0012466487&office_id=003&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '진영이 반도체, 2차전지에 이어 스마트팜용 필름으로 산업용 필름 포트폴리오를 다각화한다. 진영은 D&W그룹, 청토씨앤디와 에어돔 스마트팜 공동사...뉴시스|2024-04-02 14:57',
#   '뉴시스',
#   '2024-04-02 14:57'),
#  ('다원시스, 3일 기업설명회 개최',
#   'https://finance.naver.com/news/news_read.naver?article_id=0012466486&office_id=003&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '다원시스는 3일 오전 9시10분 서울 여의도 등 기관투자자 회의실에서 국내 기관투자자를 대상으로 회사 사업현황에 대한 이해도와 기업가치 제고를 위해 기업설명회(IR)를 개...뉴시스|2024-04-02 14:56',
#   '뉴시스',
#   '2024-04-02 14:56'),
#  ('동학개미 “모처럼 달리는 코스피, 더 간다?”…빚투 규모 20조 육박',
#   'https://finance.naver.com/news/news_read.naver?article_id=0005282077&office_id=009&mode=LSS2D&type=0§ion_id=101§ion_id2=258§ion_id3=&date=20240402&page=1',
#   '코스피 지수가 무난히 2700선에 안착하면서 3000선까지 도달할 수 있다는 증권가의 긍정적인 전망이 나오자 개인 투자자들의 투자열기도 모처럼 ...매일경제|2024-04-02 14:56',
#   '매일경제',
#   '2024-04-02 14:56')]

# %%
result = [ tuple( re.sub(r'[\t\n]|^\s+|\s+$','',ele)  for ele in t) for t in result_list ]

# %%
columns = ['제목','URL','요약','언론사','작성일시']
df = pd.DataFrame(result,columns = columns)
df
# Out:
#                                           제목  \
# 0       “중개형 ISA도 나무에서” 나무증권, 중개형 ISA 이벤트 실시
# 1            ‘자본시장 메카’ 여의도 새 터전서 새 출발하는 증권사들
# 2         뜨거웠던 1분기 IPO, 상장 첫날 매도시 평균 168% 수익
# 3   한국은행 “통안계정 7일물 3.50%, 28일물 3.52%에 각각 낙찰”
# 4               LIG넥스원, 3000억 규모 토지·건물 취득 결정
# 5                한투운용, 베트남그로스UH 펀드 1년 수익률 1위
# 6                  미래산업, 넵콘 상하이 참가…글로벌 시장 공략
# 7               한화에어로스페이스 "인적분할 검토하나 확정 안 돼"
# 8                  우리은행 '사고 Zero 서포터즈' 2기 출범
# 9                   이수그룹-지용킴, 2024 SS 컬렉션 출시
# 10       "FDA 승인 획득"…코어라인소프트, 미국 간다 [엔터프라이스]
# 11         '사면초가' 철강업계…포스코 '인내의 시간' [엔터프라이스]
# 12    한투證, 글로벌 대체투자 운용사 TPG 안젤로고든과 부동산투자 MOU
# 13              KB국민은행, LG유플러스 손잡고 환전수수료 낮춘다
# 14        지배구조 우수 기업에 감사인지정 면제... '밸류업' 인센티브
# 15            "한화에어로스페이스, 인적분할 추진 검토"…주가 '쑥'
# 16             [특징주] ‘인적분할 추진’ 한화에어로, 사상 최고가
# 17                  진영, 에어돔 스마트팜 공동사업 진행 MOU
# 18                         다원시스, 3일 기업설명회 개최
# 19    동학개미 “모처럼 달리는 코스피, 더 간다?”…빚투 규모 20조 육박
#
#                                                   URL  \
# 0   https://finance.naver.com/news/news_read.naver...
# 1   https://finance.naver.com/news/news_read.naver...
# 2   https://finance.naver.com/news/news_read.naver...
# 3   https://finance.naver.com/news/news_read.naver...
# 4   https://finance.naver.com/news/news_read.naver...
# 5   https://finance.naver.com/news/news_read.naver...
# 6   https://finance.naver.com/news/news_read.naver...
# 7   https://finance.naver.com/news/news_read.naver...
# 8   https://finance.naver.com/news/news_read.naver...
# 9   https://finance.naver.com/news/news_read.naver...
# 10  https://finance.naver.com/news/news_read.naver...
# 11  https://finance.naver.com/news/news_read.naver...
# 12  https://finance.naver.com/news/news_read.naver...
# 13  https://finance.naver.com/news/news_read.naver...
# 14  https://finance.naver.com/news/news_read.naver...
# 15  https://finance.naver.com/news/news_read.naver...
# 16  https://finance.naver.com/news/news_read.naver...
# 17  https://finance.naver.com/news/news_read.naver...
# 18  https://finance.naver.com/news/news_read.naver...
# 19  https://finance.naver.com/news/news_read.naver...
#
#                                                    요약     언론사  \
# 0   NH투자증권 나무증권은 ‘중개형 ISA(Individual Savings Accou...    매일경제
# 1   최근 증권사들이 자본시장의 메카(중심지)인 여의도에서 입지를 선점하기 위해 입성 혹...    데일리안
# 2   엔젤로보틱스를 끝으로 올해 1분기 기업공개(IPO) 시장이 마무리됐다. 1분기 상장...  아이뉴스24
# 3   한국은행은 2일 통화안정계정예치금 경쟁입찰 실시 결과 7일물이 3.50%에 4조68...    이데일리
# 4   LIG넥스원은 미래기술을 위한 R&D 인프라 확보 목적으로 재단법인 세종연구소로부터...   헤럴드경제
# 5   한국투자신탁운용은 한국투자베트남그로스UH(C-W)가 운용설정액 500억원 이상의 베...     뉴시스
# 6   반도체 후공정 검사장비 제조 전문기업 미래산업은 이달 말 중국 상하이에서 개최되는 ...     뉴시스
# 7   한화에어로스페이스는 인적분할을 추진한다는 언론 보도에 대해 "주주가치와 경영효율성 ...     뉴시스
# 8   우리은행(행장 조병규)은 지난 1일 '사고 Zero 서포터즈' 2기 발대식을 열고,...    전자신문
# 9   이수그룹이 지용킴 디자이너와 2024 SS 컬렉션을 한정판으로 출시한다고 2일 밝혔...   아시아경제
# 10  다음 소식은 정 기자가 준비했죠. 어떤 기업 소식입니까? 오늘 따끈따끈한 자료를 낸...  한국경제TV
# 11  왼쪽에서 레프트 훅이 날아오고, 오른쪽에선 라이트 스트레이트가 꽂힙니다. 우리나라 ...  한국경제TV
# 12  한국투자증권은 글로벌 사모펀드 운용사인 텍사스퍼시픽그룹(TPG)의 대체투자 전문 운...    매일경제
# 13  KB국민은행(행장 이재근)이 LG유플러스(대표 황현식)와 마케팅 업무제휴를 체결하고...    전자신문
# 14  금융당국이 '밸류업 프로그램'의 일환으로 추가 인센티브를 내놨다. 지배구조 개선에 ...    한국일보
# 15  한화에어로스페이스가 인적분할을 추진을 검토하고 있다는 소식에 주가가 급등 중이다. ...  한국경제TV
# 16  한화에어로스페이스가 인적분할을 추진한다는 사실이 알려지면서 주가가 역대 최고가를 찍...    조선비즈
# 17  진영이 반도체, 2차전지에 이어 스마트팜용 필름으로 산업용 필름 포트폴리오를 다각화...     뉴시스
# 18  다원시스는 3일 오전 9시10분 서울 여의도 등 기관투자자 회의실에서 국내 기관투자...     뉴시스
# 19  코스피 지수가 무난히 2700선에 안착하면서 3000선까지 도달할 수 있다는 증권가...    매일경제
#
#                 작성일시
# 0   2024-04-02 15:15
# 1   2024-04-02 15:15
# 2   2024-04-02 15:13
# 3   2024-04-02 15:11
# 4   2024-04-02 15:11
# 5   2024-04-02 15:09
# 6   2024-04-02 15:07
# 7   2024-04-02 15:07
# 8   2024-04-02 15:05
# 9   2024-04-02 15:04
# 10  2024-04-02 15:03
# 11  2024-04-02 15:03
# 12  2024-04-02 15:02
# 13  2024-04-02 15:02
# 14  2024-04-02 15:01
# 15  2024-04-02 15:00
# 16  2024-04-02 14:59
# 17  2024-04-02 14:57
# 18  2024-04-02 14:56
# 19  2024-04-02 14:56

# %%
df['언론사'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='언론사'>

# %%
df.to_excel('실시간뉴스속보.xlsx',index=False)
df.to_csv('실시간뉴스속보.csv',index=False)

# %%
df = pd.read_excel('실시간뉴스속보.xlsx')
df2 = pd.read_csv('실시간뉴스속보.csv')

# %%
df.shape, df2.shape
# Out:
# ((20, 5), (20, 5))
