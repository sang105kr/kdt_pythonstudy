# %% [markdown]
# ## 웹크롤링, 웹스크래핑
# * [위치전략](https://www.selenium.dev/documentation/webdriver/elements/locators/)
# * [요소찾기](https://www.selenium.dev/documentation/webdriver/elements/finders/)
# * [요소와상호작용하기](https://www.selenium.dev/documentation/webdriver/elements/interactions/)

# %% [markdown]
# ### seleninum 기본 패키지 import

# %%
# selenium 라이브러리에서 webdriver 모듈 임포트, 웹 브라우저를 자동으로 제어하기 위한 기능을 제공
from selenium import webdriver
# 크롬 웹드라이버를 위한 서비스 객체를 사용하기 위해 Service 모듈 임포트
from selenium.webdriver.chrome.service import Service
# 크롬 드라이버의 자동 업데이트를 위해 webdriver_manager에서 ChromeDriverManager를 임포트
from webdriver_manager.chrome import ChromeDriverManager
# 크롬 옵션을 설정하기 위한 Options 모듈을 임포트 일반적으로 브라우저의 특정 옵션을 설정할 때 사용
from selenium.webdriver.chrome.options import Options
# html요소 접근
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### HTTP 요청,응답, HTML파서 import

# %%
# http요청,응답 수행
import requests
# html문서 파싱 (DOM 요소 다루듯 쉽게 접근하는 기능 제공)
from bs4 import BeautifulSoup

# %% [markdown]
# ### selenium 보조 유틸 import

# %%
import time
# import pyautogui
# import pyperclip

# %% [markdown]
# ### 정규표현식을 사용하기위한 패키지 import

# %%
# 정규표현식
import re

# %%
# http요청
# url = 'http://www.naver.com'
keyword='호랑이'
url = f'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query={keyword}'
headers = {
    'User-Agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
}
params = {}
res = requests.get(url,headers=headers, params=params)
res.status_code
# Out:
# 200

# %%
res.text
# Out:
# '<!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="호랑이 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'호랑이\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'호랑이\'의 네이버 통합검색 결과입니다."> <title>호랑이 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240314.css"> <link rel="stylesheet" type="text/css" h
# ...

# %%
# r' '  : raw string - 이스케이프 시퀀스를 무시하고 문자 그대로 표현하라는 의미
# 이스케이프 문자 :  보통 \(역슬래쉬)문자로 새로운기능을 부여하거나 기존 기능을 변경,소멸하는 역할
# 이스케이프 시퀀스 : 이스케이프문자 뒤에 연이어 나오는 문자의 집합
pattern = r'호랑이'
findall = re.findall(pattern, res.text)
print(len(findall))
# [ word for word in findall]
# Out:
# 485

# %%
html = BeautifulSoup(res.text,'html.parser')
print(html.select_one('p'))
print(html.select_one('p').text)
print(html.select_one('p')['class'])
# Out:
# <p class="dsc">검색어와 포함된 키워드를 기반으로 AI 기술을 활용하여 연관된 추천 질문을 제공합니다.</p>
# 검색어와 포함된 키워드를 기반으로 AI 기술을 활용하여 연관된 추천 질문을 제공합니다.
# ['dsc']

# %%
[ele.text for ele in html.select('p')]
# Out:
# ['검색어와 포함된 키워드를 기반으로 AI 기술을 활용하여 연관된 추천 질문을 제공합니다.',
#  '  ',
#  'ON/OFF 설정은 해당기기(브라우저)에 저장됩니다.',
#  '동일한 시간대・연령대・남녀별 사용자 그룹의 관심사에 맞춰 자동완성을 제공합니다. 자세히 보기',
#  '광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다.',
#  '고양잇과의 포유류. 몸의 길이는 2미터 정도이며, 등은 누런 갈색이고 검은 가로무늬가 있으며 배는 흰색이다. 꼬리는 길고 검은 줄무늬가 있다. 삼림이나 대숲에 혼자 또는 암수 한 쌍이 같이 사는데 시베리아 남부에서 인도, 자바 등지에 분포한다.',
#  '몹시 사납고 무서운 사람을 비유적으로 이르는 말.',
#  '(동물) tiger, (암컷) tigress',
#  '(비유적)',
#  '서치피드는 검색 결과 하단에서 사용자의 관심사와 관련된 새로운 콘텐츠를 탐색하고 발견할 수 있는 피드 영역으로서, 입력된 검색어와 일치하지 않는 콘텐츠가 노출될 수 있습니다.',
#  '국내 봄 여행지 모아보기',
#  '네이버 Cue: 사전 신청하기',
#  '대화형 AI 서비스 시작하기 ',
#  '최대 5% 적립 네이버플러스 멤버십']
